# %% [markdown]
# # Модели ML

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, ElasticNet
from sklearn.metrics import r2_score, mean_squared_error as MSE, mean_absolute_percentage_error as MAPE
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, cross_validate, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_classif, chi2, mutual_info_regression, f_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('../0_data/expanded_data_with_OSM_v3.csv', sep = ',')

# %%
df.describe()
# Out:
#         Unnamed: 0           id    atm_group          lat          lon  \
# count  5957.000000  5957.000000  5957.000000  5957.000000  5957.000000
# mean   2978.000000  4432.957277  4416.499580    54.160017    63.519692
# std    1719.782108  2547.059400  2444.317377     4.346200    33.020176
# min       0.000000     5.000000    32.000000    42.057080    19.941530
# 25%    1489.000000  2249.000000  1942.000000    52.248916    37.858986
# 50%    2978.000000  4401.000000  5478.000000    55.069638    48.578510
# 75%    4467.000000  6677.000000  5478.000000    56.122756    84.951080
# max    5956.000000  8811.000000  8083.000000    69.491912   173.706490
#
#             target  distance_to_retail  distance_to_apartments  \
# count  5957.000000         5672.000000             5826.000000
# mean      0.000735          788.515928              370.822299
# std       0.086220         1151.004172              764.881539
# min      -0.145001            0.422055                0.273087
# 25%      -0.061486          163.057855               67.016546
# 50%      -0.015589          434.502845              172.078937
# 75%       0.040243          913.762856              361.379677
# max       0.218608         9966.501559             9906.394257
#
#        distance_to_commercial  distance_to_office  ...  \
# count             5627.000000         5061.000000  ...
# mean              1137.791859         1813.033225  ...
# std               1459.851038         1901.792184  ...
# min                  0.590193            1.376734  ...
# 25%                298.646774          525.237015  ...
# 50%                656.595756         1145.872658  ...
# 75%               1346.875954         2362.855527  ...
# max               9938.201676         9976.544942  ...
#
#        distance_to_parking_underground    population        salary  \
# count                      2478.000000  5.957000e+03   5957.000000
# mean                       3572.456733  2.371803e+07  48177.347490
# std                        2567.605368  1.162307e+07   8381.451295
# min                           6.818753  8.124053e+06  24399.000000
# 25%                        1457.666322  1.394196e+07  42845.000000
# 50%                        2965.817736  1.700393e+07  44500.000000
# 75%                        5250.133224  3.925096e+07  60000.000000
# max                        9956.745817  3.925096e+07  60000.000000
#
#        population_density  happy_index         avgC         avgR         avgS  \
# count         5957.000000  5957.000000  5957.000000  5957.000000  5957.000000
# mean            26.990442    80.831459     0.000735     0.000735     0.000735
# std             24.027636     2.918031     0.045815     0.017085     0.031926
# min              1.168499    76.000000    -0.145001    -0.025588    -0.081613
# 25%              3.778890    80.000000    -0.025645    -0.016940    -0.022416
# 50%             28.034260    80.000000    -0.006291     0.002931    -0.004482
# 75%             60.367053    84.000000     0.032903     0.005491     0.034486
# max             60.367053    86.000000     0.218043     0.031983     0.099002
#
#               avgA      capital
# count  5957.000000  5957.000000
# mean      0.000735     0.120195
# std       0.070497     0.325216
# min      -0.088685     0.000000
# 25%      -0.034377     0.000000
# 50%      -0.034377     0.000000
# 75%       0.003110     0.000000
# max       0.151132     1.000000
#
# [8 rows x 52 columns]

# %%
df.isnull().sum().head(56)
# Out:
# Unnamed: 0                            0
# id                                    0
# atm_group                             0
# address                               0
# address_rus                           0
# lat                                   0
# lon                                   0
# target                                0
# geometry                              0
# distance_to_retail                  285
# distance_to_apartments              131
# distance_to_commercial              330
# distance_to_office                  896
# distance_to_train_station          1438
# distance_to_residential             478
# distance_to_house                   147
# distance_to_detached                952
# distance_to_supermarket             212
# distance_to_cinema                 1172
# distance_to_pharmacy                205
# distance_to_cafe                    214
# distance_to_bank                    268
# distance_to_sber_bank               538
# distance_to_restaurant              568
# distance_to_sber_atm               1737
# distance_to_atm                     347
# distance_to_fast_food               477
# distance_to_vtb_bank               1422
# distance_to_convenience             139
# distance_to_clothes                 499
# distance_to_mobile_phone_shop       168
# distance_to_shoe_shop               813
# distance_to_vending_any            2060
# distance_to_alfa_bank              2180
# distance_to_vtb_atm                3978
# distance_to_ros_bank               2968
# distance_to_alfa_atm               3843
# distance_to_ros_atm                4445
# distance_to_vending_parking        4535
# distance_to_bus_stop                114
# distance_to_railway_station         738
# distance_to_tram_stop              3017
# distance_to_railway_halt           1578
# distance_to_airport                5786
# distance_to_parking                 610
# distance_to_parking_underground    3479
# cities                                0
# regions                               0
# states                                0
# population                            0
# salary                                0
# population_density                    0
# happy_index                           0
# avgC                                  0
# avgR                                  0
# avgS                                  0
# dtype: int64

# %%
df.regions.value_counts()
# Out:
# regions
# Central Federal District            1687
# Siberian Federal District           1169
# Volga Federal District              1095
# Far Eastern Federal District         814
# Northwestern Federal District        430
# Southern Federal District            363
# Ural Federal District                336
# North Caucasian Federal District      63
# Name: count, dtype: int64

# %% [markdown]
# ### Заполняем пропуски максимальными значениями

# %%
#замения пропуски максимальными значениями расстояний
df = df.fillna(df.max())

# %%
len(df)
# Out:
# 5957

# %% [markdown]
# OneHotEncoding для категориальных фичей

# %%
df['capital'] = np.where((df['cities'] == 'Moscow') | (df['cities'] == 'Saint Petersburg'), 1, 0)

# %%
df.drop(['Unnamed: 0','id','address','address_rus','lat','lon','geometry'], axis =1,  inplace = True)

# %%
df = df.merge(df.groupby('cities').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgC'}),
         how='left', on='cities')

df = df.merge(df.groupby('regions').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgR'}),
         how='left', on='regions')

df = df.merge(df.groupby('states').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgS'}),
         how='left', on='states')

df = df.merge(df.groupby('atm_group').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgA'}),
         how='left', on='atm_group')

# %%
df['atm_group'] = df['atm_group'].astype(int)
df = pd.get_dummies(df, columns=['atm_group'], drop_first=True) 
df.drop(columns=['cities'], inplace=True)
X = pd.get_dummies(df, drop_first=True) 

y = X['target']
X = X.loc[:, X.columns != 'target'].reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5957 entries, 0 to 5956
# Data columns (total 55 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   target                           5957 non-null   float64
#  1   distance_to_retail               5957 non-null   float64
#  2   distance_to_apartments           5957 non-null   float64
#  3   distance_to_commercial           5957 non-null   float64
#  4   distance_to_office               5957 non-null   float64
#  5   distance_to_train_station        5957 non-null   float64
#  6   distance_to_residential          5957 non-null   float64
#  7   distance_to_house                5957 non-null   float64
#  8   distance_to_detached             5957 non-null   float64
#  9   distance_to_supermarket          5957 non-null   float64
#  10  distance_to_cinema               5957 non-null   float64
#  11  distance_to_pharmacy             5957 non-null   float64
#  12  distance_to_cafe                 5957 non-null   float64
#  13  distance_to_bank                 5957 non-null   float64
#  14  distance_to_sber_bank            5957 non-null   float64
#  15  distance_to_restaurant           5957 non-null   float64
#  16  distance_to_sber_atm             5957 non-null   float64
#  17  distance_to_atm                  5957 non-null   float64
#  18  distance_to_fast_food            5957 non-null   float64
#  19  distance_to_vtb_bank             5957 non-null   float64
#  20  distance_to_convenience          5957 non-null   float64
#  21  distance_to_clothes              5957 non-null   float64
#  22  distance_to_mobile_phone_shop    5957 non-null   float64
#  23  distance_to_shoe_shop            5957 non-null   float64
#  24  distance_to_vending_any          5957 non-null   float64
#  25  distance_to_alfa_bank            5957 non-null   float64
#  26  distance_to_vtb_atm              5957 non-null   float64
#  27  distance_to_ros_bank             5957 non-null   float64
#  28  distance_to_alfa_atm             5957 non-null   float64
#  29  distance_to_ros_atm              5957 non-null   float64
#  30  distance_to_vending_parking      5957 non-null   float64
#  31  distance_to_bus_stop             5957 non-null   float64
#  32  distance_to_railway_station      5957 non-null   float64
#  33  distance_to_tram_stop            5957 non-null   float64
#  34  distance_to_railway_halt         5957 non-null   float64
#  35  distance_to_airport              5957 non-null   float64
#  36  distance_to_parking              5957 non-null   float64
#  37  distance_to_parking_underground  5957 non-null   float64
#  38  regions                          5957 non-null   object
#  39  states                           5957 non-null   object
#  40  population                       5957 non-null   int64
#  41  salary                           5957 non-null   int64
#  42  population_density               5957 non-null   float64
#  43  happy_index                      5957 non-null   int64
#  44  avgC                             5957 non-null   float64
#  45  avgR                             5957 non-null   float64
#  46  avgS                             5957 non-null   float64
#  47  avgA                             5957 non-null   float64
#  48  capital                          5957 non-null   int64
#  49  atm_group_496                    5957 non-null   bool
#  50  atm_group_1022                   5957 non-null   bool
#  51  atm_group_1942                   5957 non-null   bool
#  52  atm_group_3185                   5957 non-null   bool
#  53  atm_group_5478                   5957 non-null   bool
#  54  atm_group_8083                   5957 non-null   bool
# dtypes: bool(6), float64(43), int64(4), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ## Модели

# %% [markdown]
# ### Разбиваем на train и test

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# ### Стандартизация признаков

# %%
normalizer = StandardScaler()
X_real_norm_np = normalizer.fit_transform(X_train)
X_train = pd.DataFrame(data=X_real_norm_np)

normalizer = StandardScaler()
X_real_norm_np = normalizer.fit_transform(X_test)
X_test = pd.DataFrame(data=X_real_norm_np)

# %% [markdown]
# ### Linear Regression

# %%
lr = LinearRegression()

lr.fit(X_train, y_train)

lr_train = lr.predict(X_train)
lr_test = lr.predict(X_test)

lr_r2_train = r2_score(y_train, lr_train)
lr_mse_train = MSE(y_train, lr_train)
lr_rmse_train = MSE(y_train, lr_train, squared=False)
# lr_mape_train = MAPE(y_train, lr_train)

lr_r2_test = r2_score(y_test, lr_test)
lr_mse_test = MSE(y_test, lr_test)
lr_rmse_test = MSE(y_test, lr_test, squared=False)
# lr_mape_test = MAPE(y_test, lr_test)

print(f"TRAIN: R2: {lr_r2_train}, MSE: {lr_mse_train}, \
RMSE: {lr_rmse_train}\n")
print(f"TEST: R2: {lr_r2_test}, MSE: {lr_mse_test }, \
RMSE: {lr_rmse_test }")
# Out:
# TRAIN: R2: 0.7398320098414939, MSE: 0.0019174906185465148, RMSE: 0.043789160971027
#
# TEST: R2: -1.6426667862636061e+25, MSE: 1.2485039423086556e+23, RMSE: 353341752742.1088

# %% [markdown]
# ### Ridge (L2-регуляризация)

# %%
ridge = Ridge()

ridge.fit(X_train, y_train)

ridge_train = ridge.predict(X_train)
ridge_test = ridge.predict(X_test)

ridge_r2_train = r2_score(y_train, ridge_train)
ridge_mse_train = MSE(y_train, ridge_train)
ridge_rmse_train = MSE(y_train, ridge_train, squared=False)
# ridge_mape_train = MAPE(y_train, ridge_train)

ridge_r2_test = r2_score(y_test, ridge_test)
ridge_mse_test = MSE(y_test, ridge_test)
ridge_rmse_test = MSE(y_test, ridge_test, squared=False)
# ridge_mape_test = MAPE(y_test, ridge_test)

print(f"TRAIN: R2: {ridge_r2_train}, MSE: {ridge_mse_train}, \
RMSE: {ridge_rmse_train}\n")
print(f"TEST: R2: {ridge_r2_test}, MSE: {ridge_mse_test}, \
RMSE: {ridge_rmse_test}")

# model.coef_
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# TRAIN: R2: 0.7400241781368243, MSE: 0.001916074299408816, RMSE: 0.043772985954910776
#
# TEST: R2: 0.7284874109835695, MSE: 0.002063623253407918, RMSE: 0.045427120241194226

# %% [markdown]
# ### ElasticNet с GridSearchCV

# %%
params = {'alpha': np.arange(1, 10, 1), 'l1_ratio': np.arange(0, 1.1, 0.1)}
en = GridSearchCV(ElasticNet(), param_grid=params, cv=10, n_jobs=-1)

en.fit(X_train, y_train)

en_train = en.predict(X_train)
en_test = en.predict(X_test)

en_r2_train = r2_score(y_train, en_train)
en_mse_train = MSE(y_train, en_train)
en_rmse_train = MSE(y_train, en_train, squared=False)
# en_mape_train = MAPE(y_train, en_train)

en_r2_test = r2_score(y_test, en_test)
en_mse_test = MSE(y_test, en_test)
en_rmse_test = MSE(y_test, en_test, squared=False)
# en_mape_test = MAPE(y_test, en_test)

print(f"TRAIN: R2: {en_r2_train}, MSE: {en_mse_train}, \
RMSE: {en_rmse_train}\n")
print(f"TEST: R2: {en_r2_test}, MSE: {en_mse_train}, \
RMSE: {en_rmse_test}")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.851e+00, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.881e+00, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.855e+00, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.954e+00, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.896e+00, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.914e+00, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.900e+00, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.843e+00, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.872e+00, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.885e+00, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.510e+00, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.475e+00, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.512e+00, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.515e+00, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.543e+00, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.517e+00, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.587e+00, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.446e+00, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.026e+01, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.027e+01, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.639e+00, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.504e+00, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.470e+00, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.492e+00, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.038e+01, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.021e+01, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.549e+00, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.520e+00, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.081e+01, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.083e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.477e+00, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.028e+01, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.485e+00, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.028e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.561e+00, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.094e+01, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.479e+00, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.080e+01, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.030e+01, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.025e+01, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.083e+01, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+01, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.539e+00, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.158e+01, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.025e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.085e+01, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.137e+01, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.518e+00, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.186e+01, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.172e+01, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.023e+01, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.081e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.126e+01, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e+01, tolerance: 2.951e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.200e+01, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.160e+01, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.077e+01, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.128e+01, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.224e+01, tolerance: 2.993e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.188e+01, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.163e+01, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.081e+01, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.212e+01, tolerance: 2.966e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.191e+01, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.159e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.075e+01, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.119e+01, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.215e+01, tolerance: 2.976e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.187e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.153e+01, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.124e+01, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.181e+01, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.159e+01, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.204e+01, tolerance: 2.938e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.187e+01, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.118e+01, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.152e+01, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.211e+01, tolerance: 2.967e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.180e+01, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.126e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.161e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.203e+01, tolerance: 2.943e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.189e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.122e+01, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.156e+01, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.213e+01, tolerance: 2.970e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.184e+01, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.208e+01, tolerance: 2.955e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# TRAIN: R2: 0.674669157620029, MSE: 0.0023977539965903214, RMSE: 0.04896686631376692
#
# TEST: R2: 0.6629130399591959, MSE: 0.0023977539965903214, RMSE: 0.05061639344054323
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.657e+00, tolerance: 3.292e-03 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Дерево решений

# %%
tree = DecisionTreeRegressor()

tree.fit(X_train, y_train)

tree_train = tree.predict(X_train)
tree_test = tree.predict(X_test)

tree_r2_train = r2_score(y_train, tree_train)
tree_mse_train = MSE(y_train, tree_train)
tree_rmse_train = MSE(y_train, tree_train, squared=False)
# tree_mape_train = MAPE(y_train, tree_train)

tree_r2_test = r2_score(y_test, tree_test)
tree_mse_test = MSE(y_test, tree_test)
tree_rmse_test = MSE(y_test, tree_test, squared=False)
# tree_mape_test = MAPE(y_test, tree_test)


print(f"TRAIN: R2: {tree_r2_train}, MSE: {tree_mse_train}, \
RMSE: {tree_rmse_train}\n")
print(f"TEST: R2: {tree_r2_test}, MSE: {tree_mse_test}, \
RMSE: {tree_rmse_test}")
# Out:
# TRAIN: R2: 0.9857258319407025, MSE: 0.00010520350072498861, RMSE: 0.010256875777983695
#
# TEST: R2: 0.5748657653689091, MSE: 0.0032312199429964795, RMSE: 0.056843820622794874

# %% [markdown]
# ### Дерево решений с GridSearchCV

# %%
params = {'max_depth' : np.arange(3, 10, 1),
          'max_features' : ["auto", "sqrt", "log2"],
          'min_samples_leaf': np.arange(3, 8, 1)}

gs_tree = GridSearchCV(DecisionTreeRegressor(), params, cv=5, scoring='r2')

gs_tree.fit(X_train, y_train)

gs_tree_train = gs_tree.predict(X_train)
gs_tree_test = gs_tree.predict(X_test)

gs_tree_r2_train = r2_score(y_train, gs_tree_train)
gs_tree_mse_train = MSE(y_train, gs_tree_train)
gs_tree_rmse_train = MSE(y_train, gs_tree_train, squared=False)
# gs_tree_mape_train = MAPE(y_train, gs_tree_train)

gs_tree_r2_test = r2_score(y_test, gs_tree_test)
gs_tree_mse_test = MSE(y_test, gs_tree_test)
gs_tree_rmse_test = MSE(y_test, gs_tree_test, squared=False)
# gs_tree_mape_test = MAPE(y_test, gs_tree_test)

print(f"TRAIN: R2: {gs_tree_r2_train}, MSE: {gs_tree_mse_train}, \
RMSE: {gs_tree_rmse_train}\n")
print(f"TEST: R2: {gs_tree_r2_test}, MSE: {gs_tree_mse_test}, \
RMSE: {gs_tree_rmse_test}")
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# TRAIN: R2: 0.7521743318919765, MSE: 0.0018265252129696739, RMSE: 0.042737866265990326
#
# TEST: R2: 0.7375073867173635, MSE: 0.001995067199573133, RMSE: 0.04466617511689503
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/tree/_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(

# %% [markdown]
# ### Метод ближайших соседей

# %%
knn = KNeighborsRegressor(n_neighbors=10) #лучший результат достигается с 10-ю соседями
knn.fit(X_train, y_train)

knn_train = knn.predict(X_train)
knn_test = knn.predict(X_test)

knn_r2_train = r2_score(y_train, knn_train)
knn_mse_train = MSE(y_train, knn_train)
knn_rmse_train = MSE(y_train, knn_train, squared=False)
# knn_mape_train = MAPE(y_train, knn_train)

knn_r2_test = r2_score(y_test, knn_test)
knn_mse_test = MSE(y_test, knn_test)
knn_rmse_test = MSE(y_test, knn_test, squared=False)
# knn_mape_test = MAPE(y_test, knn_test)

print(f"TRAIN: R2: {knn_r2_train}, MSE: {knn_mse_train}, \
RMSE: {knn_rmse_train}\n")
print(f"TEST: R2: {knn_r2_test}, MSE: {knn_mse_train}, \
RMSE: {knn_rmse_test}")

# %% [markdown]
# ### Метод опорных векторов

# %%
svr = SVR()
svr.fit(X_train, y_train)

svr_train = svr.predict(X_train)
svr_test = svr.predict(X_test)

svr_r2_train = r2_score(y_train, svr_train)
svr_mse_train = MSE(y_train, svr_train)
svr_rmse_train = MSE(y_train, svr_train, squared=False)
# svr_mape_train = MAPE(y_train, svr_train)

svr_r2_test = r2_score(y_test, svr_test)
svr_mse_test = MSE(y_test, svr_test)
svr_rmse_test = MSE(y_test, svr_test, squared=False)
# svr_mape_test = MAPE(y_test, svr_test)

print(f"TRAIN: R2: {svr_r2_train}, MSE: {svr_mse_train}, \
RMSE: {svr_rmse_train}\n")
print(f"TEST: R2: {svr_r2_test}, MSE: {svr_mse_train}, \
RMSE: {svr_rmse_test}")
# Out:
# TRAIN: R2: 0.0007414802206411331, MSE: 0.007364737053210281, RMSE: 0.08581804619781483
#
# TEST: R2: 0.011391960544705815, MSE: 0.007364737053210281, RMSE: 0.0866826719807246

# %% [markdown]
# ### Случайный лес

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=42, n_jobs=-1, warm_start=True)

rf.fit(X_train, y_train)

rf_train = rf.predict(X_train)
rf_test = rf.predict(X_test)

rf_r2_train = r2_score(y_train, rf_train)
rf_mse_train = MSE(y_train, rf_train)
rf_rmse_train = MSE(y_train, rf_train, squared=False)
rf_mape_train = MAPE(y_train, rf_train)

rf_r2_test = r2_score(y_test, rf_test)
rf_mse_test = MSE(y_test, rf_test)
rf_rmse_test = MSE(y_test, rf_test, squared=False)
rf_mape_test = MAPE(y_test, rf_test)

print(f"TRAIN: R2: {rf_r2_train}, MSE: {rf_mse_train}, \
RMSE: {rf_rmse_train}, MAPE: {rf_mape_train}\n")
print(f"TEST: R2: {rf_r2_test}, MSE: {rf_mse_test }, \
RMSE: {rf_rmse_test }, MAPE: {rf_mape_test}")
# Out:
# TRAIN: R2: 0.9583419211666154, MSE: 0.00030702845227431787, RMSE: 0.017522227377657153, MAPE: 1.0125190661271022
#
# TEST: R2: 0.7754435473690098, MSE: 0.0017067345533803694, RMSE: 0.041312643989224046, MAPE: 2.5826418938122258

# %%
from scipy.stats import randint

param_grid = {
               'min_samples_leaf': [1, 2, 3],
#                'max_depth': randint(30, 40),
               'max_features' : ['auto', 'sqrt'],
               'max_leaf_nodes': np.arange(2600, 5000),
             }

rf_opt = RandomizedSearchCV(estimator = RandomForestRegressor(), param_distributions = param_grid, 
                            cv = 5, n_jobs=-1, error_score='raise')

rf_opt.fit(X_train, y_train)
pred_rf_opt_train = rf_opt.predict(X_train)
pred_rf_opt = rf_opt.predict(X_test)

rf_opt_r2_train = r2_score(y_train, pred_rf_opt_train)
rf_opt_mse_train = MSE(y_train, pred_rf_opt_train)
rf_opt_rmse_train = MSE(y_train, pred_rf_opt_train, squared=False)
rf_opt_mape_train = MAPE(y_train, pred_rf_opt_train)

rf_opt_r2_test = r2_score(y_test, pred_rf_opt)
rf_opt_mse_test = MSE(y_test, pred_rf_opt)
rf_opt_rmse_test = MSE(y_test, pred_rf_opt, squared=False)
rf_opt_mape_test = MAPE(y_test, pred_rf_opt)

print(f"TRAIN: R2: {rf_opt_r2_train}, MSE: {rf_opt_mse_train}, \
RMSE: {rf_opt_rmse_train}, MAPE: {rf_opt_mape_train}\n")
print(f"TEST: R2: {rf_opt_r2_test}, MSE: {rf_opt_mse_test }, \
RMSE: {rf_opt_rmse_test }, MAPE: {rf_opt_mape_test}")
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# TRAIN: R2: 0.9501735008410783, MSE: 0.00036723135937683854, RMSE: 0.01916328153988347, MAPE: 1.1143980888078426
#
# TEST: R2: 0.7765215311486493, MSE: 0.001698541370137856, RMSE: 0.041213363975024606, MAPE: 2.450785081931379

# %%
from sklearn.ensemble import StackingRegressor
estimators = [('rf', rf),
#               ('lr', lr),
#               ('cb', CatBoostRegressor())
             ]

stacked = StackingRegressor(estimators=estimators, cv=2, n_jobs=-1)

stacked.fit(X, y)

stacked_preds = stacked.predict(X_test)

stacked_r2_test = r2_score(y_test, stacked_preds)
stacked_mse_test = MSE(y_test, stacked_preds)
stacked_rmse_test = MSE(y_test, stacked_preds, squared=False)

print(f"TEST: R2: {stacked_r2_test}, MSE: {stacked_mse_test}, \
RMSE: {stacked_rmse_test}")
# Out:
# TEST: R2: 0.2614913906779156, MSE: 0.005613012437323018, RMSE: 0.0749200402917872
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Catboost

# %%
from catboost import CatBoostRegressor

# %%
at_features= ['regions','states','atm_group','cities']
cb  = CatBoostRegressor(cat_features= cat_features,
                           eval_metric = 'RMSE',
                           random_seed = 42)
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis = 1), y, test_size=0.25, random_state=42)
cb.fit(X_train, y_train)
y_pred = cb.predict(X_test)

# measure quality
cb_r2_test = r2_score(y_test, y_pred)
cb_mse_test = MSE(y_test, y_pred)
cb_rmse_test = MSE(y_test, y_pred, squared=False)
# mape_test = MAPE(y_test, y_pred)

# print(f"TRAIN: R2: {r2_train}, MSE: {cb_mse_train}, \
# RMSE: {cb_rmse_train}\n")
print(f"TEST: R2: {cb_r2_test}, MSE: {cb_mse_test}, \
RMSE: {cb_rmse_test}")
# Out:
# TEST: R2: 0.7857882717048564, MSE: 0.0016281097877041961, RMSE: 0.040349842474341785

# %% [markdown]
# Посмотрим на важность признаков

# %%
# оценка проводилась без StandardScaler
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))
feat_importances = pd.Series(cb.feature_importances_, index=X_train.columns).nlargest(20).plot(kind='barh')

# %% [markdown]
# ## Итог

# %%
metrics = pd.DataFrame({'model': ['LinearRegression', 'Ridge', 'ElasticNet', 'Tree', 
                        'Tree with GridSearchCV', 'SVR', 'Random Forest', 'Catboost'],
                        'R2':    [lr_r2_test, ridge_r2_test, en_r2_test, tree_r2_test, 
                                  gs_tree_r2_test, svr_r2_test, rf_r2_test, 
                                  cb_r2_test],
                        'MSE':   [lr_mse_test, ridge_mse_test, en_mse_test, tree_mse_test,
                                  gs_tree_mse_test, svr_mse_test, rf_mse_test, 
                                  cb_mse_test],
                        'RMSE':  [lr_rmse_test, ridge_rmse_test, en_rmse_test, tree_rmse_test,
                                  gs_tree_rmse_test, svr_rmse_test, rf_rmse_test, 
                                  cb_rmse_test],
#                         'MAPE':  [lr_mape_test, ridge_mape_test, en_mape_test, tree_mape_test,
#                                   gs_tree_mape_test, knn_mape_test, svr_mape_test, rf_mape_test, cb_mape_test]
                        })

metrics.iloc[1:, 1:] = metrics.iloc[1:, 1:].applymap(lambda x: f'{x:.6f}')
norm_metrics = metrics.iloc[1:, :]
norm_metrics
# Out:
# /var/folders/40/syqp3b6j0cdf65gmn816vtx40000gn/T/ipykernel_26982/1451007385.py:16: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   metrics.iloc[1:, 1:] = metrics.iloc[1:, 1:].applymap(lambda x: f'{x:.6f}')
# /var/folders/40/syqp3b6j0cdf65gmn816vtx40000gn/T/ipykernel_26982/1451007385.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0.728487' '0.662913' '0.574866' '0.737507' '0.580122' '0.775444'
#  '0.785788']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.iloc[1:, 1:] = metrics.iloc[1:, 1:].applymap(lambda x: f'{x:.6f}')
# /var/folders/40/syqp3b6j0cdf65gmn816vtx40000gn/T/ipykernel_26982/1451007385.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0.002064' '0.002562' '0.003231' '0.001995' '0.003191' '0.001707'
#  '0.001628']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.iloc[1:, 1:] = metrics.iloc[1:, 1:].applymap(lambda x: f'{x:.6f}')
# /var/folders/40/syqp3b6j0cdf65gmn816vtx40000gn/T/ipykernel_26982/1451007385.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['0.045427' '0.050616' '0.056844' '0.044666' '0.056491' '0.041313'
#  '0.040350']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   metrics.iloc[1:, 1:] = metrics.iloc[1:, 1:].applymap(lambda x: f'{x:.6f}')
#                     model        R2       MSE      RMSE
# 1                   Ridge  0.728487  0.002064  0.045427
# 2              ElasticNet  0.662913  0.002562  0.050616
# 3                    Tree  0.574866  0.003231  0.056844
# 4  Tree with GridSearchCV  0.737507  0.001995  0.044666
# 5                     SVR  0.580122  0.003191  0.056491
# 6           Random Forest  0.775444  0.001707  0.041313
# 7                Catboost  0.785788  0.001628  0.040350

# %% [markdown]
# ## Методы снижения размерности

# %%
from sklearn.feature_selection import f_classif, chi2, mutual_info_classif, SelectFromModel

# %%
pipe0 = Pipeline([
    ('selector_', SelectKBest(score_func=f_regression, k=100)), 
    ('model_', RandomForestRegressor())]
)

# %%
cv_res = cross_validate(pipe0, X_train, y_train, cv=5, scoring='r2', n_jobs=-1,
                         return_train_score=True)
cv_res
# Out:
# {'fit_time': array([6.65998411, 6.62683797, 6.5740869 , 6.5826571 , 6.71564889]),
#  'score_time': array([0.020504  , 0.01987314, 0.0191741 , 0.01922679, 0.01830506]),
#  'test_score': array([0.79552793, 0.75785618, 0.75374624, 0.7431545 , 0.76820509]),
#  'train_score': array([0.9575819 , 0.95908787, 0.95960834, 0.96080023, 0.95925206])}

# %%
from sklearn.decomposition import PCA

pipe1 = Pipeline([
    ('selector_', PCA(n_components=110)), 
    ('model_', RandomForestRegressor(random_state=42))]
)

# %% [markdown]
# ## Финальный pipeline модели

# %%
# данные предобрабатываются из БД
df = pd.read_csv('../0_data/expanded_data_with_OSM_v3.csv', sep = ',')
df = df[df['target'].notnull()]
#замения пропуски максимальными значениями расстояний
df = df.fillna(df.max())

df['atm_group'] = df['atm_group'].astype(int)

y = df['target'].reset_index(drop=True)
X = df.loc[:, ~df.columns.isin(['target', 'Unnamed: 0','id','address','address_rus','lat','lon','test_train_flag','geometry'])].reset_index(drop=True)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5957 entries, 0 to 5956
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   atm_group                        5957 non-null   int64
#  1   distance_to_retail               5957 non-null   float64
#  2   distance_to_apartments           5957 non-null   float64
#  3   distance_to_commercial           5957 non-null   float64
#  4   distance_to_office               5957 non-null   float64
#  5   distance_to_train_station        5957 non-null   float64
#  6   distance_to_residential          5957 non-null   float64
#  7   distance_to_house                5957 non-null   float64
#  8   distance_to_detached             5957 non-null   float64
#  9   distance_to_supermarket          5957 non-null   float64
#  10  distance_to_cinema               5957 non-null   float64
#  11  distance_to_pharmacy             5957 non-null   float64
#  12  distance_to_cafe                 5957 non-null   float64
#  13  distance_to_bank                 5957 non-null   float64
#  14  distance_to_sber_bank            5957 non-null   float64
#  15  distance_to_restaurant           5957 non-null   float64
#  16  distance_to_sber_atm             5957 non-null   float64
#  17  distance_to_atm                  5957 non-null   float64
#  18  distance_to_fast_food            5957 non-null   float64
#  19  distance_to_vtb_bank             5957 non-null   float64
#  20  distance_to_convenience          5957 non-null   float64
#  21  distance_to_clothes              5957 non-null   float64
#  22  distance_to_mobile_phone_shop    5957 non-null   float64
#  23  distance_to_shoe_shop            5957 non-null   float64
#  24  distance_to_vending_any          5957 non-null   float64
#  25  distance_to_alfa_bank            5957 non-null   float64
#  26  distance_to_vtb_atm              5957 non-null   float64
#  27  distance_to_ros_bank             5957 non-null   float64
#  28  distance_to_alfa_atm             5957 non-null   float64
#  29  distance_to_ros_atm              5957 non-null   float64
#  30  distance_to_vending_parking      5957 non-null   float64
#  31  distance_to_bus_stop             5957 non-null   float64
#  32  distance_to_railway_station      5957 non-null   float64
#  33  distance_to_tram_stop            5957 non-null   float64
#  34  distance_to_railway_halt         5957 non-null   float64
#  35  distance_to_airport              5957 non-null   float64
#  36  distance_to_parking              5957 non-null   float64
#  37  distance_to_parking_underground  5957 non-null   float64
#  38  cities                           5957 non-null   object
#  39  regions                          5957 non-null   object
#  40  states                           5957 non-null   object
#  41  population                       5957 non-null   int64
#  42  salary                           5957 non-null   int64
#  43  population_density               5957 non-null   float64
#  44  happy_index                      5957 non-null   int64
#  45  avgC                             5957 non-null   float64
#  46  avgR                             5957 non-null   float64
#  47  avgS                             5957 non-null   float64
#  48  avgA                             5957 non-null   float64
#  49  capital                          5957 non-null   int64
# dtypes: float64(42), int64(5), object(3)
# memory usage: 2.3+ MB

# %%
X.columns
# Out:
# Index(['atm_group', 'distance_to_retail', 'distance_to_apartments',
#        'distance_to_commercial', 'distance_to_office',
#        'distance_to_train_station', 'distance_to_residential',
#        'distance_to_house', 'distance_to_detached', 'distance_to_supermarket',
#        'distance_to_cinema', 'distance_to_pharmacy', 'distance_to_cafe',
#        'distance_to_bank', 'distance_to_sber_bank', 'distance_to_restaurant',
#        'distance_to_sber_atm', 'distance_to_atm', 'distance_to_fast_food',
#        'distance_to_vtb_bank', 'distance_to_convenience',
#        'distance_to_clothes', 'distance_to_mobile_phone_shop',
#        'distance_to_shoe_shop', 'distance_to_vending_any',
#        'distance_to_alfa_bank', 'distance_to_vtb_atm', 'distance_to_ros_bank',
#        'distance_to_alfa_atm', 'distance_to_ros_atm',
#        'distance_to_vending_parking', 'distance_to_bus_stop',
#        'distance_to_railway_station', 'distance_to_tram_stop',
#        'distance_to_railway_halt', 'distance_to_airport',
#        'distance_to_parking', 'distance_to_parking_underground', 'cities',
#        'regions', 'states', 'population', 'salary', 'population_density',
#        'happy_index', 'avgC', 'avgR', 'avgS', 'avgA', 'capital'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from catboost import CatBoostRegressor

cat_features= ['regions','states','atm_group','cities']
cb  = CatBoostRegressor(cat_features= cat_features,
                           eval_metric = 'RMSE',
                           random_seed = 42)

cb.fit(X_train, y_train)
y_pred = cb.predict(X_test)

# measure quality
cb_r2_test = r2_score(y_test, y_pred)
cb_mse_test = MSE(y_test, y_pred)
cb_rmse_test = MSE(y_test, y_pred, squared=False)
# mape_test = MAPE(y_test, y_pred)

# print(f"TRAIN: R2: {r2_train}, MSE: {cb_mse_train}, \
# RMSE: {cb_rmse_train}\n")
print(f"TEST: R2: {cb_r2_test}, MSE: {cb_mse_test}, \
RMSE: {cb_rmse_test}")
# Out:
# Learning rate set to 0.051866
# 0:	learn: 0.0829511	total: 7.36ms	remaining: 7.35s
# 1:	learn: 0.0801314	total: 12.7ms	remaining: 6.35s
# 2:	learn: 0.0776024	total: 18.2ms	remaining: 6.05s
# 3:	learn: 0.0751961	total: 26.5ms	remaining: 6.6s
# 4:	learn: 0.0730127	total: 31.4ms	remaining: 6.24s
# 5:	learn: 0.0710030	total: 37.8ms	remaining: 6.26s
# 6:	learn: 0.0689966	total: 43.3ms	remaining: 6.14s
# 7:	learn: 0.0671455	total: 48.6ms	remaining: 6.03s
# 8:	learn: 0.0654218	total: 55.6ms	remaining: 6.12s
# 9:	learn: 0.0637370	total: 60.1ms	remaining: 5.95s
# 10:	learn: 0.0623308	total: 64.3ms	remaining: 5.78s
# 11:	learn: 0.0609180	total: 68.7ms	remaining: 5.66s
# 12:	learn: 0.0596156	total: 74.1ms	remaining: 5.63s
# 13:	learn: 0.0583469	total: 77.6ms	remaining: 5.46s
# 14:	learn: 0.0572174	total: 83.6ms	remaining: 5.49s
# 15:	learn: 0.0561910	total: 98.3ms	remaining: 6.04s
# 16:	learn: 0.0552156	total: 105ms	remaining: 6.05s
# 17:	learn: 0.0543379	total: 108ms	remaining: 5.89s
# 18:	learn: 0.0534623	total: 118ms	remaining: 6.07s
# 19:	learn: 0.0526597	total: 130ms	remaining: 6.35s
# 20:	learn: 0.0519057	total: 138ms	remaining: 6.42s
# 21:	learn: 0.0512624	total: 143ms	remaining: 6.38s
# 22:	learn: 0.0505886	total: 148ms	remaining: 6.27s
# 23:	learn: 0.0500111	total: 158ms	remaining: 6.41s
# 24:	learn: 0.0494462	total: 162ms	remaining: 6.33s
# 25:	learn: 0.0490010	total: 167ms	remaining: 6.24s
# 26:	learn: 0.0485582	total: 172ms	remaining: 6.18s
# 27:	learn: 0.0481327	total: 176ms	remaining: 6.12s
# 28:	learn: 0.0477856	total: 180ms	remaining: 6.03s
# 29:	learn: 0.0473931	total: 187ms	remaining: 6.06s
# 30:	learn: 0.0470543	total: 191ms	remaining: 5.96s
# 31:	learn: 0.0467523	total: 201ms	remaining: 6.08s
# 32:	learn: 0.0464981	total: 214ms	remaining: 6.26s
# 33:	learn: 0.0462310	total: 230ms	remaining: 6.53s
# 34:	learn: 0.0459678	total: 246ms	remaining: 6.78s
# 35:	learn: 0.0457428	total: 254ms	remaining: 6.81s
# 36:	learn: 0.0454796	total: 259ms	remaining: 6.74s
# 37:	learn: 0.0452428	total: 270ms	remaining: 6.85s
# 38:	learn: 0.0450268	total: 282ms	remaining: 6.96s
# 39:	learn: 0.0448104	total: 288ms	remaining: 6.91s
# 40:	learn: 0.0446328	total: 297ms	remaining: 6.94s
# 41:	learn: 0.0444557	total: 314ms	remaining: 7.16s
# 42:	learn: 0.0443110	total: 324ms	remaining: 7.21s
# 43:	learn: 0.0441762	total: 334ms	remaining: 7.26s
# 44:	learn: 0.0440495	total: 348ms	remaining: 7.38s
# 45:	learn: 0.0439077	total: 353ms	remaining: 7.33s
# 46:	learn: 0.0437934	total: 381ms	remaining: 7.71s
# 47:	learn: 0.0436802	total: 399ms	remaining: 7.91s
# 48:	learn: 0.0435681	total: 414ms	remaining: 8.04s
# 49:	learn: 0.0434311	total: 420ms	remaining: 7.97s
# 50:	learn: 0.0433440	total: 429ms	remaining: 7.99s
# 51:	learn: 0.0432363	total: 440ms	remaining: 8.02s
# 52:	learn: 0.0431467	total: 445ms	remaining: 7.95s
# 53:	learn: 0.0430640	total: 456ms	remaining: 7.99s
# 54:	learn: 0.0429810	total: 468ms	remaining: 8.05s
# 55:	learn: 0.0428696	total: 478ms	remaining: 8.06s
# 56:	learn: 0.0427928	total: 484ms	remaining: 8.01s
# 57:	learn: 0.0427000	total: 490ms	remaining: 7.96s
# 58:	learn: 0.0426217	total: 497ms	remaining: 7.92s
# 59:	learn: 0.0425281	total: 505ms	remaining: 7.92s
# 60:	learn: 0.0424637	total: 520ms	remaining: 8s
# 61:	learn: 0.0423944	total: 529ms	remaining: 8.01s
# 62:	learn: 0.0423199	total: 539ms	remaining: 8.02s
# 63:	learn: 0.0422648	total: 549ms	remaining: 8.03s
# 64:	learn: 0.0422010	total: 556ms	remaining: 8s
# 65:	learn: 0.0421267	total: 565ms	remaining: 8s
# 66:	learn: 0.0420633	total: 583ms	remaining: 8.12s
# 67:	learn: 0.0420056	total: 616ms	remaining: 8.44s
# 68:	learn: 0.0419482	total: 629ms	remaining: 8.48s
# 69:	learn: 0.0418961	total: 655ms	remaining: 8.7s
# 70:	learn: 0.0418270	total: 662ms	remaining: 8.66s
# 71:	learn: 0.0417747	total: 674ms	remaining: 8.69s
# 72:	learn: 0.0417382	total: 698ms	remaining: 8.87s
# 73:	learn: 0.0416892	total: 714ms	remaining: 8.93s
# 74:	learn: 0.0416197	total: 724ms	remaining: 8.93s
# 75:	learn: 0.0415657	total: 757ms	remaining: 9.2s
# 76:	learn: 0.0415117	total: 781ms	remaining: 9.36s
# 77:	learn: 0.0414719	total: 791ms	remaining: 9.35s
# 78:	learn: 0.0414357	total: 800ms	remaining: 9.33s
# 79:	learn: 0.0413808	total: 816ms	remaining: 9.38s
# 80:	learn: 0.0413484	total: 833ms	remaining: 9.45s
# 81:	learn: 0.0413151	total: 840ms	remaining: 9.4s
# 82:	learn: 0.0412719	total: 862ms	remaining: 9.53s
# 83:	learn: 0.0412240	total: 889ms	remaining: 9.7s
# 84:	learn: 0.0411823	total: 923ms	remaining: 9.93s
# 85:	learn: 0.0411451	total: 932ms	remaining: 9.9s
# 86:	learn: 0.0411024	total: 941ms	remaining: 9.88s
# 87:	learn: 0.0410581	total: 954ms	remaining: 9.89s
# 88:	learn: 0.0410197	total: 980ms	remaining: 10s
# 89:	learn: 0.0409816	total: 995ms	remaining: 10.1s
# 90:	learn: 0.0409449	total: 1s	remaining: 10s
# 91:	learn: 0.0409068	total: 1.01s	remaining: 10s
# 92:	learn: 0.0408769	total: 1.03s	remaining: 10.1s
# 93:	learn: 0.0408447	total: 1.05s	remaining: 10.1s
# 94:	learn: 0.0408258	total: 1.06s	remaining: 10.1s
# 95:	learn: 0.0407928	total: 1.07s	remaining: 10.1s
# 96:	learn: 0.0407693	total: 1.09s	remaining: 10.2s
# 97:	learn: 0.0407315	total: 1.09s	remaining: 10.1s
# 98:	learn: 0.0406906	total: 1.11s	remaining: 10.1s
# 99:	learn: 0.0406559	total: 1.13s	remaining: 10.2s
# 100:	learn: 0.0406333	total: 1.16s	remaining: 10.3s
# 101:	learn: 0.0406033	total: 1.17s	remaining: 10.3s
# 102:	learn: 0.0405612	total: 1.19s	remaining: 10.3s
# 103:	learn: 0.0405310	total: 1.19s	remaining: 10.2s
# 104:	learn: 0.0404949	total: 1.19s	remaining: 10.2s
# 105:	learn: 0.0404738	total: 1.2s	remaining: 10.1s
# 106:	learn: 0.0404311	total: 1.22s	remaining: 10.2s
# 107:	learn: 0.0404171	total: 1.24s	remaining: 10.2s
# 108:	learn: 0.0403836	total: 1.25s	remaining: 10.2s
# 109:	learn: 0.0403525	total: 1.27s	remaining: 10.3s
# 110:	learn: 0.0403255	total: 1.28s	remaining: 10.3s
# 111:	learn: 0.0402914	total: 1.29s	remaining: 10.3s
# 112:	learn: 0.0402584	total: 1.33s	remaining: 10.4s
# 113:	learn: 0.0402197	total: 1.33s	remaining: 10.4s
# 114:	learn: 0.0402056	total: 1.35s	remaining: 10.4s
# 115:	learn: 0.0401783	total: 1.36s	remaining: 10.4s
# 116:	learn: 0.0401419	total: 1.36s	remaining: 10.3s
# 117:	learn: 0.0401149	total: 1.37s	remaining: 10.2s
# 118:	learn: 0.0400752	total: 1.37s	remaining: 10.2s
# 119:	learn: 0.0400347	total: 1.38s	remaining: 10.1s
# 120:	learn: 0.0400033	total: 1.39s	remaining: 10.1s
# 121:	learn: 0.0399783	total: 1.41s	remaining: 10.1s
# 122:	learn: 0.0399459	total: 1.41s	remaining: 10.1s
# 123:	learn: 0.0399192	total: 1.42s	remaining: 10s
# 124:	learn: 0.0398924	total: 1.43s	remaining: 10s
# 125:	learn: 0.0398778	total: 1.44s	remaining: 10s
# 126:	learn: 0.0398404	total: 1.45s	remaining: 9.96s
# 127:	learn: 0.0398252	total: 1.46s	remaining: 9.94s
# 128:	learn: 0.0397917	total: 1.48s	remaining: 9.97s
# 129:	learn: 0.0397696	total: 1.48s	remaining: 9.92s
# 130:	learn: 0.0397345	total: 1.49s	remaining: 9.88s
# 131:	learn: 0.0397001	total: 1.5s	remaining: 9.9s
# 132:	learn: 0.0396757	total: 1.51s	remaining: 9.86s
# 133:	learn: 0.0396423	total: 1.52s	remaining: 9.85s
# 134:	learn: 0.0395967	total: 1.54s	remaining: 9.86s
# 135:	learn: 0.0395775	total: 1.56s	remaining: 9.89s
# 136:	learn: 0.0395541	total: 1.57s	remaining: 9.92s
# 137:	learn: 0.0394989	total: 1.58s	remaining: 9.89s
# 138:	learn: 0.0394762	total: 1.59s	remaining: 9.84s
# 139:	learn: 0.0394370	total: 1.6s	remaining: 9.82s
# 140:	learn: 0.0394013	total: 1.6s	remaining: 9.77s
# 141:	learn: 0.0393676	total: 1.61s	remaining: 9.72s
# 142:	learn: 0.0393145	total: 1.62s	remaining: 9.72s
# 143:	learn: 0.0392641	total: 1.63s	remaining: 9.71s
# 144:	learn: 0.0392293	total: 1.65s	remaining: 9.72s
# 145:	learn: 0.0391944	total: 1.66s	remaining: 9.71s
# 146:	learn: 0.0391823	total: 1.69s	remaining: 9.82s
# 147:	learn: 0.0391542	total: 1.74s	remaining: 10s
# 148:	learn: 0.0391104	total: 1.74s	remaining: 9.96s
# 149:	learn: 0.0390876	total: 1.75s	remaining: 9.93s
# 150:	learn: 0.0390592	total: 1.76s	remaining: 9.88s
# 151:	learn: 0.0390312	total: 1.76s	remaining: 9.83s
# 152:	learn: 0.0389896	total: 1.77s	remaining: 9.8s
# 153:	learn: 0.0389780	total: 1.78s	remaining: 9.78s
# 154:	learn: 0.0389457	total: 1.81s	remaining: 9.86s
# 155:	learn: 0.0389214	total: 1.81s	remaining: 9.82s
# 156:	learn: 0.0388947	total: 1.82s	remaining: 9.79s
# 157:	learn: 0.0388598	total: 1.83s	remaining: 9.74s
# 158:	learn: 0.0388254	total: 1.84s	remaining: 9.73s
# 159:	learn: 0.0388111	total: 1.85s	remaining: 9.7s
# 160:	learn: 0.0387857	total: 1.85s	remaining: 9.65s
# 161:	learn: 0.0387546	total: 1.86s	remaining: 9.61s
# 162:	learn: 0.0387313	total: 1.86s	remaining: 9.57s
# 163:	learn: 0.0387072	total: 1.87s	remaining: 9.53s
# 164:	learn: 0.0386635	total: 1.88s	remaining: 9.5s
# 165:	learn: 0.0386259	total: 1.88s	remaining: 9.46s
# 166:	learn: 0.0385993	total: 1.9s	remaining: 9.47s
# 167:	learn: 0.0385543	total: 1.91s	remaining: 9.47s
# 168:	learn: 0.0385286	total: 1.93s	remaining: 9.48s
# 169:	learn: 0.0384921	total: 1.94s	remaining: 9.49s
# 170:	learn: 0.0384666	total: 1.97s	remaining: 9.54s
# 171:	learn: 0.0384343	total: 1.98s	remaining: 9.52s
# 172:	learn: 0.0384191	total: 2s	remaining: 9.56s
# 173:	learn: 0.0383878	total: 2.01s	remaining: 9.55s
# 174:	learn: 0.0383613	total: 2.02s	remaining: 9.51s
# 175:	learn: 0.0383241	total: 2.06s	remaining: 9.63s
# 176:	learn: 0.0382846	total: 2.07s	remaining: 9.61s
# 177:	learn: 0.0382590	total: 2.08s	remaining: 9.63s
# 178:	learn: 0.0382131	total: 2.1s	remaining: 9.62s
# 179:	learn: 0.0381924	total: 2.11s	remaining: 9.6s
# 180:	learn: 0.0381653	total: 2.12s	remaining: 9.57s
# 181:	learn: 0.0381248	total: 2.12s	remaining: 9.54s
# 182:	learn: 0.0381018	total: 2.13s	remaining: 9.51s
# 183:	learn: 0.0380639	total: 2.13s	remaining: 9.47s
# 184:	learn: 0.0380319	total: 2.14s	remaining: 9.44s
# 185:	learn: 0.0379907	total: 2.15s	remaining: 9.43s
# 186:	learn: 0.0379678	total: 2.16s	remaining: 9.41s
# 187:	learn: 0.0379344	total: 2.18s	remaining: 9.42s
# 188:	learn: 0.0379004	total: 2.19s	remaining: 9.4s
# 189:	learn: 0.0378764	total: 2.2s	remaining: 9.39s
# 190:	learn: 0.0378489	total: 2.22s	remaining: 9.42s
# 191:	learn: 0.0378348	total: 2.24s	remaining: 9.41s
# 192:	learn: 0.0378169	total: 2.24s	remaining: 9.38s
# 193:	learn: 0.0377989	total: 2.26s	remaining: 9.38s
# 194:	learn: 0.0377690	total: 2.26s	remaining: 9.34s
# 195:	learn: 0.0377361	total: 2.29s	remaining: 9.39s
# 196:	learn: 0.0376828	total: 2.29s	remaining: 9.35s
# 197:	learn: 0.0376549	total: 2.31s	remaining: 9.34s
# 198:	learn: 0.0376304	total: 2.31s	remaining: 9.32s
# 199:	learn: 0.0375997	total: 2.33s	remaining: 9.31s
# 200:	learn: 0.0375872	total: 2.34s	remaining: 9.29s
# 201:	learn: 0.0375620	total: 2.35s	remaining: 9.28s
# 202:	learn: 0.0375209	total: 2.37s	remaining: 9.29s
# 203:	learn: 0.0374968	total: 2.37s	remaining: 9.25s
# 204:	learn: 0.0374684	total: 2.38s	remaining: 9.21s
# 205:	learn: 0.0374188	total: 2.38s	remaining: 9.19s
# 206:	learn: 0.0373905	total: 2.39s	remaining: 9.15s
# 207:	learn: 0.0373592	total: 2.4s	remaining: 9.12s
# 208:	learn: 0.0373405	total: 2.41s	remaining: 9.13s
# 209:	learn: 0.0373141	total: 2.44s	remaining: 9.19s
# 210:	learn: 0.0372866	total: 2.45s	remaining: 9.16s
# 211:	learn: 0.0372671	total: 2.46s	remaining: 9.15s
# 212:	learn: 0.0372397	total: 2.48s	remaining: 9.18s
# 213:	learn: 0.0372196	total: 2.5s	remaining: 9.18s
# 214:	learn: 0.0371766	total: 2.52s	remaining: 9.2s
# 215:	learn: 0.0371534	total: 2.54s	remaining: 9.21s
# 216:	learn: 0.0371250	total: 2.55s	remaining: 9.19s
# 217:	learn: 0.0370918	total: 2.56s	remaining: 9.18s
# 218:	learn: 0.0370669	total: 2.57s	remaining: 9.18s
# 219:	learn: 0.0370182	total: 2.58s	remaining: 9.14s
# 220:	learn: 0.0370002	total: 2.6s	remaining: 9.18s
# 221:	learn: 0.0369641	total: 2.61s	remaining: 9.15s
# 222:	learn: 0.0369469	total: 2.62s	remaining: 9.14s
# 223:	learn: 0.0369103	total: 2.65s	remaining: 9.2s
# 224:	learn: 0.0368832	total: 2.66s	remaining: 9.17s
# 225:	learn: 0.0368602	total: 2.67s	remaining: 9.15s
# 226:	learn: 0.0368308	total: 2.68s	remaining: 9.12s
# 227:	learn: 0.0368025	total: 2.69s	remaining: 9.12s
# 228:	learn: 0.0367847	total: 2.71s	remaining: 9.12s
# 229:	learn: 0.0367753	total: 2.71s	remaining: 9.09s
# 230:	learn: 0.0367625	total: 2.73s	remaining: 9.1s
# 231:	learn: 0.0367258	total: 2.74s	remaining: 9.08s
# 232:	learn: 0.0367141	total: 2.75s	remaining: 9.04s
# 233:	learn: 0.0366945	total: 2.75s	remaining: 9.01s
# 234:	learn: 0.0366755	total: 2.8s	remaining: 9.12s
# 235:	learn: 0.0366456	total: 2.83s	remaining: 9.16s
# 236:	learn: 0.0366116	total: 2.85s	remaining: 9.16s
# 237:	learn: 0.0365771	total: 2.85s	remaining: 9.13s
# 238:	learn: 0.0365564	total: 2.86s	remaining: 9.1s
# 239:	learn: 0.0365258	total: 2.88s	remaining: 9.12s
# 240:	learn: 0.0364996	total: 2.91s	remaining: 9.15s
# 241:	learn: 0.0364616	total: 2.92s	remaining: 9.15s
# 242:	learn: 0.0364478	total: 2.94s	remaining: 9.15s
# 243:	learn: 0.0364109	total: 2.94s	remaining: 9.12s
# 244:	learn: 0.0364015	total: 2.95s	remaining: 9.09s
# 245:	learn: 0.0363682	total: 2.96s	remaining: 9.07s
# 246:	learn: 0.0363530	total: 2.96s	remaining: 9.04s
# 247:	learn: 0.0363262	total: 2.97s	remaining: 9.01s
# 248:	learn: 0.0362846	total: 2.98s	remaining: 8.99s
# 249:	learn: 0.0362652	total: 3s	remaining: 9s
# 250:	learn: 0.0362429	total: 3.01s	remaining: 8.97s
# 251:	learn: 0.0362171	total: 3.01s	remaining: 8.95s
# 252:	learn: 0.0361970	total: 3.03s	remaining: 8.95s
# 253:	learn: 0.0361863	total: 3.04s	remaining: 8.92s
# 254:	learn: 0.0361659	total: 3.04s	remaining: 8.9s
# 255:	learn: 0.0361448	total: 3.05s	remaining: 8.88s
# 256:	learn: 0.0361176	total: 3.07s	remaining: 8.86s
# 257:	learn: 0.0360911	total: 3.08s	remaining: 8.86s
# 258:	learn: 0.0360575	total: 3.09s	remaining: 8.83s
# 259:	learn: 0.0360280	total: 3.09s	remaining: 8.8s
# 260:	learn: 0.0360113	total: 3.1s	remaining: 8.77s
# 261:	learn: 0.0360071	total: 3.1s	remaining: 8.74s
# 262:	learn: 0.0359864	total: 3.12s	remaining: 8.76s
# 263:	learn: 0.0359640	total: 3.13s	remaining: 8.73s
# 264:	learn: 0.0359568	total: 3.14s	remaining: 8.72s
# 265:	learn: 0.0359287	total: 3.15s	remaining: 8.7s
# 266:	learn: 0.0358989	total: 3.16s	remaining: 8.68s
# 267:	learn: 0.0358774	total: 3.17s	remaining: 8.67s
# 268:	learn: 0.0358635	total: 3.19s	remaining: 8.65s
# 269:	learn: 0.0358542	total: 3.21s	remaining: 8.67s
# 270:	learn: 0.0358236	total: 3.22s	remaining: 8.65s
# 271:	learn: 0.0357883	total: 3.23s	remaining: 8.65s
# 272:	learn: 0.0357578	total: 3.24s	remaining: 8.63s
# 273:	learn: 0.0357217	total: 3.25s	remaining: 8.61s
# 274:	learn: 0.0357019	total: 3.25s	remaining: 8.57s
# 275:	learn: 0.0356927	total: 3.26s	remaining: 8.54s
# 276:	learn: 0.0356705	total: 3.27s	remaining: 8.53s
# 277:	learn: 0.0356566	total: 3.27s	remaining: 8.5s
# 278:	learn: 0.0356382	total: 3.29s	remaining: 8.5s
# 279:	learn: 0.0356270	total: 3.31s	remaining: 8.5s
# 280:	learn: 0.0356008	total: 3.32s	remaining: 8.51s
# 281:	learn: 0.0355654	total: 3.33s	remaining: 8.49s
# 282:	learn: 0.0355331	total: 3.35s	remaining: 8.5s
# 283:	learn: 0.0354920	total: 3.36s	remaining: 8.47s
# 284:	learn: 0.0354605	total: 3.38s	remaining: 8.47s
# 285:	learn: 0.0354319	total: 3.38s	remaining: 8.45s
# 286:	learn: 0.0354244	total: 3.39s	remaining: 8.43s
# 287:	learn: 0.0354020	total: 3.4s	remaining: 8.42s
# 288:	learn: 0.0353766	total: 3.41s	remaining: 8.4s
# 289:	learn: 0.0353565	total: 3.42s	remaining: 8.38s
# 290:	learn: 0.0353237	total: 3.43s	remaining: 8.36s
# 291:	learn: 0.0353144	total: 3.44s	remaining: 8.33s
# 292:	learn: 0.0352926	total: 3.44s	remaining: 8.3s
# 293:	learn: 0.0352813	total: 3.44s	remaining: 8.27s
# 294:	learn: 0.0352533	total: 3.45s	remaining: 8.25s
# 295:	learn: 0.0352229	total: 3.46s	remaining: 8.22s
# 296:	learn: 0.0351968	total: 3.46s	remaining: 8.2s
# 297:	learn: 0.0351728	total: 3.47s	remaining: 8.17s
# 298:	learn: 0.0351510	total: 3.48s	remaining: 8.15s
# 299:	learn: 0.0351196	total: 3.48s	remaining: 8.13s
# 300:	learn: 0.0351047	total: 3.5s	remaining: 8.13s
# 301:	learn: 0.0350857	total: 3.54s	remaining: 8.18s
# 302:	learn: 0.0350803	total: 3.54s	remaining: 8.15s
# 303:	learn: 0.0350641	total: 3.55s	remaining: 8.14s
# 304:	learn: 0.0350496	total: 3.56s	remaining: 8.12s
# 305:	learn: 0.0350395	total: 3.57s	remaining: 8.1s
# 306:	learn: 0.0349978	total: 3.58s	remaining: 8.09s
# 307:	learn: 0.0349734	total: 3.59s	remaining: 8.07s
# 308:	learn: 0.0349444	total: 3.6s	remaining: 8.06s
# 309:	learn: 0.0349090	total: 3.62s	remaining: 8.06s
# 310:	learn: 0.0348772	total: 3.63s	remaining: 8.04s
# 311:	learn: 0.0348624	total: 3.64s	remaining: 8.02s
# 312:	learn: 0.0348300	total: 3.66s	remaining: 8.03s
# 313:	learn: 0.0348239	total: 3.66s	remaining: 8s
# 314:	learn: 0.0348201	total: 3.68s	remaining: 8s
# 315:	learn: 0.0347988	total: 3.69s	remaining: 8s
# 316:	learn: 0.0347759	total: 3.7s	remaining: 7.97s
# 317:	learn: 0.0347649	total: 3.71s	remaining: 7.95s
# 318:	learn: 0.0347431	total: 3.72s	remaining: 7.94s
# 319:	learn: 0.0347156	total: 3.73s	remaining: 7.93s
# 320:	learn: 0.0347005	total: 3.74s	remaining: 7.91s
# 321:	learn: 0.0346769	total: 3.76s	remaining: 7.91s
# 322:	learn: 0.0346544	total: 3.77s	remaining: 7.9s
# 323:	learn: 0.0346419	total: 3.78s	remaining: 7.88s
# 324:	learn: 0.0346280	total: 3.79s	remaining: 7.88s
# 325:	learn: 0.0346013	total: 3.8s	remaining: 7.85s
# 326:	learn: 0.0345735	total: 3.82s	remaining: 7.86s
# 327:	learn: 0.0345524	total: 3.83s	remaining: 7.84s
# 328:	learn: 0.0345304	total: 3.83s	remaining: 7.82s
# 329:	learn: 0.0345197	total: 3.84s	remaining: 7.8s
# 330:	learn: 0.0344902	total: 3.85s	remaining: 7.78s
# 331:	learn: 0.0344568	total: 3.85s	remaining: 7.76s
# 332:	learn: 0.0344449	total: 3.86s	remaining: 7.74s
# 333:	learn: 0.0344298	total: 3.9s	remaining: 7.78s
# 334:	learn: 0.0344169	total: 3.91s	remaining: 7.76s
# 335:	learn: 0.0343789	total: 3.93s	remaining: 7.77s
# 336:	learn: 0.0343554	total: 3.96s	remaining: 7.78s
# 337:	learn: 0.0343361	total: 3.97s	remaining: 7.77s
# 338:	learn: 0.0343129	total: 3.98s	remaining: 7.76s
# 339:	learn: 0.0342991	total: 4s	remaining: 7.75s
# 340:	learn: 0.0342833	total: 4.03s	remaining: 7.79s
# 341:	learn: 0.0342563	total: 4.05s	remaining: 7.79s
# 342:	learn: 0.0342463	total: 4.06s	remaining: 7.78s
# 343:	learn: 0.0342324	total: 4.08s	remaining: 7.79s
# 344:	learn: 0.0342235	total: 4.1s	remaining: 7.79s
# 345:	learn: 0.0342007	total: 4.11s	remaining: 7.76s
# 346:	learn: 0.0341749	total: 4.12s	remaining: 7.76s
# 347:	learn: 0.0341510	total: 4.13s	remaining: 7.75s
# 348:	learn: 0.0341197	total: 4.15s	remaining: 7.73s
# 349:	learn: 0.0340734	total: 4.16s	remaining: 7.73s
# 350:	learn: 0.0340504	total: 4.19s	remaining: 7.75s
# 351:	learn: 0.0340303	total: 4.2s	remaining: 7.73s
# 352:	learn: 0.0340010	total: 4.21s	remaining: 7.73s
# 353:	learn: 0.0339726	total: 4.23s	remaining: 7.72s
# 354:	learn: 0.0339499	total: 4.25s	remaining: 7.73s
# 355:	learn: 0.0339362	total: 4.26s	remaining: 7.71s
# 356:	learn: 0.0339176	total: 4.27s	remaining: 7.69s
# 357:	learn: 0.0339134	total: 4.27s	remaining: 7.67s
# 358:	learn: 0.0339088	total: 4.28s	remaining: 7.64s
# 359:	learn: 0.0338993	total: 4.28s	remaining: 7.62s
# 360:	learn: 0.0338686	total: 4.29s	remaining: 7.59s
# 361:	learn: 0.0338481	total: 4.3s	remaining: 7.58s
# 362:	learn: 0.0338405	total: 4.32s	remaining: 7.57s
# 363:	learn: 0.0338287	total: 4.33s	remaining: 7.56s
# 364:	learn: 0.0338040	total: 4.33s	remaining: 7.54s
# 365:	learn: 0.0337903	total: 4.35s	remaining: 7.53s
# 366:	learn: 0.0337620	total: 4.36s	remaining: 7.52s
# 367:	learn: 0.0337367	total: 4.37s	remaining: 7.51s
# 368:	learn: 0.0337075	total: 4.39s	remaining: 7.51s
# 369:	learn: 0.0336991	total: 4.4s	remaining: 7.49s
# 370:	learn: 0.0336729	total: 4.41s	remaining: 7.47s
# 371:	learn: 0.0336498	total: 4.42s	remaining: 7.46s
# 372:	learn: 0.0336272	total: 4.43s	remaining: 7.44s
# 373:	learn: 0.0336183	total: 4.44s	remaining: 7.43s
# 374:	learn: 0.0335730	total: 4.45s	remaining: 7.42s
# 375:	learn: 0.0335535	total: 4.46s	remaining: 7.4s
# 376:	learn: 0.0335202	total: 4.47s	remaining: 7.38s
# 377:	learn: 0.0334886	total: 4.47s	remaining: 7.36s
# 378:	learn: 0.0334753	total: 4.48s	remaining: 7.34s
# 379:	learn: 0.0334518	total: 4.49s	remaining: 7.32s
# 380:	learn: 0.0334233	total: 4.5s	remaining: 7.3s
# 381:	learn: 0.0333885	total: 4.51s	remaining: 7.29s
# 382:	learn: 0.0333700	total: 4.51s	remaining: 7.27s
# 383:	learn: 0.0333601	total: 4.52s	remaining: 7.25s
# 384:	learn: 0.0333265	total: 4.53s	remaining: 7.24s
# 385:	learn: 0.0333104	total: 4.54s	remaining: 7.22s
# 386:	learn: 0.0332932	total: 4.54s	remaining: 7.2s
# 387:	learn: 0.0332752	total: 4.55s	remaining: 7.18s
# 388:	learn: 0.0332421	total: 4.55s	remaining: 7.16s
# 389:	learn: 0.0332120	total: 4.56s	remaining: 7.13s
# 390:	learn: 0.0331906	total: 4.57s	remaining: 7.11s
# 391:	learn: 0.0331634	total: 4.57s	remaining: 7.09s
# 392:	learn: 0.0331518	total: 4.59s	remaining: 7.09s
# 393:	learn: 0.0331464	total: 4.59s	remaining: 7.06s
# 394:	learn: 0.0331389	total: 4.6s	remaining: 7.04s
# 395:	learn: 0.0331352	total: 4.6s	remaining: 7.02s
# 396:	learn: 0.0331078	total: 4.62s	remaining: 7.01s
# 397:	learn: 0.0330799	total: 4.62s	remaining: 6.99s
# 398:	learn: 0.0330594	total: 4.63s	remaining: 6.97s
# 399:	learn: 0.0330440	total: 4.63s	remaining: 6.95s
# 400:	learn: 0.0330178	total: 4.64s	remaining: 6.93s
# 401:	learn: 0.0330121	total: 4.66s	remaining: 6.93s
# 402:	learn: 0.0329899	total: 4.67s	remaining: 6.92s
# 403:	learn: 0.0329693	total: 4.68s	remaining: 6.9s
# 404:	learn: 0.0329494	total: 4.68s	remaining: 6.88s
# 405:	learn: 0.0329455	total: 4.69s	remaining: 6.86s
# 406:	learn: 0.0329383	total: 4.71s	remaining: 6.87s
# 407:	learn: 0.0329108	total: 4.74s	remaining: 6.87s
# 408:	learn: 0.0328917	total: 4.74s	remaining: 6.85s
# 409:	learn: 0.0328847	total: 4.75s	remaining: 6.83s
# 410:	learn: 0.0328509	total: 4.76s	remaining: 6.82s
# 411:	learn: 0.0328237	total: 4.76s	remaining: 6.8s
# 412:	learn: 0.0328036	total: 4.77s	remaining: 6.78s
# 413:	learn: 0.0327832	total: 4.77s	remaining: 6.76s
# 414:	learn: 0.0327599	total: 4.78s	remaining: 6.74s
# 415:	learn: 0.0327353	total: 4.78s	remaining: 6.71s
# 416:	learn: 0.0327335	total: 4.79s	remaining: 6.69s
# 417:	learn: 0.0327117	total: 4.79s	remaining: 6.67s
# 418:	learn: 0.0326911	total: 4.8s	remaining: 6.65s
# 419:	learn: 0.0326664	total: 4.8s	remaining: 6.63s
# 420:	learn: 0.0326336	total: 4.81s	remaining: 6.62s
# 421:	learn: 0.0326143	total: 4.82s	remaining: 6.61s
# 422:	learn: 0.0325989	total: 4.83s	remaining: 6.59s
# 423:	learn: 0.0325918	total: 4.83s	remaining: 6.57s
# 424:	learn: 0.0325688	total: 4.84s	remaining: 6.55s
# 425:	learn: 0.0325405	total: 4.85s	remaining: 6.54s
# 426:	learn: 0.0325295	total: 4.86s	remaining: 6.52s
# 427:	learn: 0.0325148	total: 4.86s	remaining: 6.5s
# 428:	learn: 0.0324974	total: 4.88s	remaining: 6.49s
# 429:	learn: 0.0324701	total: 4.89s	remaining: 6.48s
# 430:	learn: 0.0324418	total: 4.9s	remaining: 6.46s
# 431:	learn: 0.0324266	total: 4.91s	remaining: 6.46s
# 432:	learn: 0.0323906	total: 4.92s	remaining: 6.44s
# 433:	learn: 0.0323688	total: 4.93s	remaining: 6.43s
# 434:	learn: 0.0323590	total: 4.96s	remaining: 6.44s
# 435:	learn: 0.0323367	total: 4.97s	remaining: 6.42s
# 436:	learn: 0.0323155	total: 4.97s	remaining: 6.41s
# 437:	learn: 0.0322945	total: 4.98s	remaining: 6.39s
# 438:	learn: 0.0322671	total: 4.99s	remaining: 6.38s
# 439:	learn: 0.0322426	total: 5s	remaining: 6.36s
# 440:	learn: 0.0322314	total: 5.01s	remaining: 6.35s
# 441:	learn: 0.0322041	total: 5.03s	remaining: 6.35s
# 442:	learn: 0.0321893	total: 5.04s	remaining: 6.33s
# 443:	learn: 0.0321719	total: 5.04s	remaining: 6.31s
# 444:	learn: 0.0321694	total: 5.06s	remaining: 6.31s
# 445:	learn: 0.0321534	total: 5.07s	remaining: 6.29s
# 446:	learn: 0.0321273	total: 5.07s	remaining: 6.27s
# 447:	learn: 0.0321233	total: 5.08s	remaining: 6.25s
# 448:	learn: 0.0321119	total: 5.08s	remaining: 6.23s
# 449:	learn: 0.0320949	total: 5.09s	remaining: 6.23s
# 450:	learn: 0.0320908	total: 5.12s	remaining: 6.23s
# 451:	learn: 0.0320691	total: 5.12s	remaining: 6.21s
# 452:	learn: 0.0320515	total: 5.13s	remaining: 6.19s
# 453:	learn: 0.0320440	total: 5.13s	remaining: 6.17s
# 454:	learn: 0.0320295	total: 5.13s	remaining: 6.15s
# 455:	learn: 0.0320268	total: 5.14s	remaining: 6.13s
# 456:	learn: 0.0320043	total: 5.14s	remaining: 6.11s
# 457:	learn: 0.0320021	total: 5.15s	remaining: 6.09s
# 458:	learn: 0.0319703	total: 5.15s	remaining: 6.08s
# 459:	learn: 0.0319454	total: 5.17s	remaining: 6.07s
# 460:	learn: 0.0319197	total: 5.17s	remaining: 6.05s
# 461:	learn: 0.0319064	total: 5.18s	remaining: 6.03s
# 462:	learn: 0.0318865	total: 5.19s	remaining: 6.02s
# 463:	learn: 0.0318640	total: 5.19s	remaining: 6s
# 464:	learn: 0.0318480	total: 5.2s	remaining: 5.98s
# 465:	learn: 0.0318283	total: 5.21s	remaining: 5.97s
# 466:	learn: 0.0318193	total: 5.22s	remaining: 5.96s
# 467:	learn: 0.0317946	total: 5.24s	remaining: 5.95s
# 468:	learn: 0.0317767	total: 5.24s	remaining: 5.93s
# 469:	learn: 0.0317603	total: 5.25s	remaining: 5.93s
# 470:	learn: 0.0317558	total: 5.27s	remaining: 5.92s
# 471:	learn: 0.0317281	total: 5.29s	remaining: 5.91s
# 472:	learn: 0.0317254	total: 5.29s	remaining: 5.89s
# 473:	learn: 0.0317125	total: 5.3s	remaining: 5.88s
# 474:	learn: 0.0317022	total: 5.33s	remaining: 5.9s
# 475:	learn: 0.0316740	total: 5.35s	remaining: 5.89s
# 476:	learn: 0.0316558	total: 5.36s	remaining: 5.88s
# 477:	learn: 0.0316397	total: 5.37s	remaining: 5.86s
# 478:	learn: 0.0316186	total: 5.39s	remaining: 5.86s
# 479:	learn: 0.0316027	total: 5.41s	remaining: 5.86s
# 480:	learn: 0.0315844	total: 5.42s	remaining: 5.85s
# 481:	learn: 0.0315701	total: 5.42s	remaining: 5.83s
# 482:	learn: 0.0315617	total: 5.44s	remaining: 5.82s
# 483:	learn: 0.0315410	total: 5.45s	remaining: 5.8s
# 484:	learn: 0.0315136	total: 5.45s	remaining: 5.79s
# 485:	learn: 0.0314849	total: 5.46s	remaining: 5.78s
# 486:	learn: 0.0314544	total: 5.49s	remaining: 5.79s
# 487:	learn: 0.0314342	total: 5.52s	remaining: 5.8s
# 488:	learn: 0.0314022	total: 5.53s	remaining: 5.78s
# 489:	learn: 0.0313835	total: 5.56s	remaining: 5.78s
# 490:	learn: 0.0313705	total: 5.56s	remaining: 5.77s
# 491:	learn: 0.0313480	total: 5.57s	remaining: 5.75s
# 492:	learn: 0.0313201	total: 5.58s	remaining: 5.73s
# 493:	learn: 0.0313050	total: 5.58s	remaining: 5.72s
# 494:	learn: 0.0312916	total: 5.59s	remaining: 5.7s
# 495:	learn: 0.0312689	total: 5.59s	remaining: 5.68s
# 496:	learn: 0.0312521	total: 5.6s	remaining: 5.66s
# 497:	learn: 0.0312473	total: 5.6s	remaining: 5.65s
# 498:	learn: 0.0312362	total: 5.63s	remaining: 5.65s
# 499:	learn: 0.0312109	total: 5.66s	remaining: 5.66s
# 500:	learn: 0.0311955	total: 5.67s	remaining: 5.64s
# 501:	learn: 0.0311632	total: 5.68s	remaining: 5.63s
# 502:	learn: 0.0311346	total: 5.68s	remaining: 5.61s
# 503:	learn: 0.0311086	total: 5.71s	remaining: 5.62s
# 504:	learn: 0.0311004	total: 5.76s	remaining: 5.65s
# 505:	learn: 0.0310862	total: 5.77s	remaining: 5.63s
# 506:	learn: 0.0310608	total: 5.77s	remaining: 5.61s
# 507:	learn: 0.0310434	total: 5.79s	remaining: 5.61s
# 508:	learn: 0.0310199	total: 5.81s	remaining: 5.61s
# 509:	learn: 0.0310138	total: 5.82s	remaining: 5.59s
# 510:	learn: 0.0309958	total: 5.83s	remaining: 5.58s
# 511:	learn: 0.0309683	total: 5.87s	remaining: 5.59s
# 512:	learn: 0.0309404	total: 5.87s	remaining: 5.57s
# 513:	learn: 0.0309147	total: 5.88s	remaining: 5.56s
# 514:	learn: 0.0308750	total: 5.89s	remaining: 5.54s
# 515:	learn: 0.0308715	total: 5.91s	remaining: 5.55s
# 516:	learn: 0.0308470	total: 5.93s	remaining: 5.54s
# 517:	learn: 0.0308233	total: 5.99s	remaining: 5.58s
# 518:	learn: 0.0308064	total: 6.02s	remaining: 5.58s
# 519:	learn: 0.0307948	total: 6.02s	remaining: 5.56s
# 520:	learn: 0.0307627	total: 6.03s	remaining: 5.54s
# 521:	learn: 0.0307408	total: 6.03s	remaining: 5.53s
# 522:	learn: 0.0307307	total: 6.04s	remaining: 5.51s
# 523:	learn: 0.0307164	total: 6.05s	remaining: 5.5s
# 524:	learn: 0.0306902	total: 6.11s	remaining: 5.53s
# 525:	learn: 0.0306628	total: 6.12s	remaining: 5.51s
# 526:	learn: 0.0306445	total: 6.13s	remaining: 5.5s
# 527:	learn: 0.0306327	total: 6.13s	remaining: 5.48s
# 528:	learn: 0.0306184	total: 6.14s	remaining: 5.47s
# 529:	learn: 0.0305973	total: 6.2s	remaining: 5.5s
# 530:	learn: 0.0305786	total: 6.22s	remaining: 5.5s
# 531:	learn: 0.0305551	total: 6.23s	remaining: 5.48s
# 532:	learn: 0.0305375	total: 6.28s	remaining: 5.5s
# 533:	learn: 0.0305206	total: 6.3s	remaining: 5.5s
# 534:	learn: 0.0305038	total: 6.32s	remaining: 5.5s
# 535:	learn: 0.0304910	total: 6.33s	remaining: 5.48s
# 536:	learn: 0.0304600	total: 6.34s	remaining: 5.47s
# 537:	learn: 0.0304406	total: 6.41s	remaining: 5.5s
# 538:	learn: 0.0304346	total: 6.41s	remaining: 5.49s
# 539:	learn: 0.0304154	total: 6.42s	remaining: 5.47s
# 540:	learn: 0.0303945	total: 6.43s	remaining: 5.45s
# 541:	learn: 0.0303750	total: 6.43s	remaining: 5.44s
# 542:	learn: 0.0303691	total: 6.44s	remaining: 5.42s
# 543:	learn: 0.0303618	total: 6.46s	remaining: 5.41s
# 544:	learn: 0.0303428	total: 6.47s	remaining: 5.4s
# 545:	learn: 0.0303180	total: 6.49s	remaining: 5.39s
# 546:	learn: 0.0303078	total: 6.53s	remaining: 5.41s
# 547:	learn: 0.0302904	total: 6.55s	remaining: 5.4s
# 548:	learn: 0.0302815	total: 6.56s	remaining: 5.39s
# 549:	learn: 0.0302607	total: 6.58s	remaining: 5.38s
# 550:	learn: 0.0302316	total: 6.62s	remaining: 5.39s
# 551:	learn: 0.0302135	total: 6.63s	remaining: 5.38s
# 552:	learn: 0.0301921	total: 6.66s	remaining: 5.39s
# 553:	learn: 0.0301858	total: 6.68s	remaining: 5.38s
# 554:	learn: 0.0301626	total: 6.7s	remaining: 5.37s
# 555:	learn: 0.0301559	total: 6.72s	remaining: 5.37s
# 556:	learn: 0.0301298	total: 6.75s	remaining: 5.37s
# 557:	learn: 0.0301093	total: 6.78s	remaining: 5.37s
# 558:	learn: 0.0300891	total: 6.81s	remaining: 5.37s
# 559:	learn: 0.0300794	total: 6.82s	remaining: 5.36s
# 560:	learn: 0.0300720	total: 6.83s	remaining: 5.35s
# 561:	learn: 0.0300447	total: 6.84s	remaining: 5.33s
# 562:	learn: 0.0300232	total: 6.85s	remaining: 5.32s
# 563:	learn: 0.0300006	total: 6.85s	remaining: 5.3s
# 564:	learn: 0.0299899	total: 6.86s	remaining: 5.28s
# 565:	learn: 0.0299689	total: 6.88s	remaining: 5.27s
# 566:	learn: 0.0299469	total: 6.92s	remaining: 5.29s
# 567:	learn: 0.0299366	total: 6.98s	remaining: 5.31s
# 568:	learn: 0.0299017	total: 6.99s	remaining: 5.29s
# 569:	learn: 0.0298738	total: 7s	remaining: 5.28s
# 570:	learn: 0.0298605	total: 7.03s	remaining: 5.28s
# 571:	learn: 0.0298368	total: 7.06s	remaining: 5.28s
# 572:	learn: 0.0298053	total: 7.06s	remaining: 5.26s
# 573:	learn: 0.0297820	total: 7.07s	remaining: 5.25s
# 574:	learn: 0.0297640	total: 7.08s	remaining: 5.23s
# 575:	learn: 0.0297476	total: 7.09s	remaining: 5.22s
# 576:	learn: 0.0297325	total: 7.09s	remaining: 5.2s
# 577:	learn: 0.0297084	total: 7.15s	remaining: 5.22s
# 578:	learn: 0.0296866	total: 7.16s	remaining: 5.21s
# 579:	learn: 0.0296775	total: 7.19s	remaining: 5.21s
# 580:	learn: 0.0296559	total: 7.2s	remaining: 5.19s
# 581:	learn: 0.0296363	total: 7.23s	remaining: 5.19s
# 582:	learn: 0.0296186	total: 7.24s	remaining: 5.17s
# 583:	learn: 0.0296041	total: 7.24s	remaining: 5.16s
# 584:	learn: 0.0295802	total: 7.26s	remaining: 5.15s
# 585:	learn: 0.0295650	total: 7.28s	remaining: 5.14s
# 586:	learn: 0.0295484	total: 7.29s	remaining: 5.13s
# 587:	learn: 0.0295334	total: 7.29s	remaining: 5.11s
# 588:	learn: 0.0295296	total: 7.3s	remaining: 5.09s
# 589:	learn: 0.0295079	total: 7.3s	remaining: 5.08s
# 590:	learn: 0.0294967	total: 7.31s	remaining: 5.06s
# 591:	learn: 0.0294937	total: 7.33s	remaining: 5.05s
# 592:	learn: 0.0294823	total: 7.33s	remaining: 5.03s
# 593:	learn: 0.0294562	total: 7.34s	remaining: 5.02s
# 594:	learn: 0.0294399	total: 7.37s	remaining: 5.01s
# 595:	learn: 0.0294316	total: 7.38s	remaining: 5s
# 596:	learn: 0.0294175	total: 7.38s	remaining: 4.98s
# 597:	learn: 0.0294039	total: 7.41s	remaining: 4.98s
# 598:	learn: 0.0293842	total: 7.46s	remaining: 4.99s
# 599:	learn: 0.0293688	total: 7.47s	remaining: 4.98s
# 600:	learn: 0.0293651	total: 7.48s	remaining: 4.96s
# 601:	learn: 0.0293471	total: 7.49s	remaining: 4.95s
# 602:	learn: 0.0293294	total: 7.5s	remaining: 4.94s
# 603:	learn: 0.0293155	total: 7.51s	remaining: 4.92s
# 604:	learn: 0.0292999	total: 7.59s	remaining: 4.96s
# 605:	learn: 0.0292772	total: 7.63s	remaining: 4.96s
# 606:	learn: 0.0292522	total: 7.64s	remaining: 4.95s
# 607:	learn: 0.0292406	total: 7.71s	remaining: 4.97s
# 608:	learn: 0.0292259	total: 7.72s	remaining: 4.96s
# 609:	learn: 0.0292184	total: 7.75s	remaining: 4.95s
# 610:	learn: 0.0292047	total: 7.75s	remaining: 4.94s
# 611:	learn: 0.0291911	total: 7.78s	remaining: 4.93s
# 612:	learn: 0.0291797	total: 7.79s	remaining: 4.92s
# 613:	learn: 0.0291596	total: 7.81s	remaining: 4.91s
# 614:	learn: 0.0291493	total: 7.84s	remaining: 4.91s
# 615:	learn: 0.0291351	total: 7.85s	remaining: 4.89s
# 616:	learn: 0.0291151	total: 7.89s	remaining: 4.89s
# 617:	learn: 0.0291001	total: 7.89s	remaining: 4.88s
# 618:	learn: 0.0290825	total: 7.92s	remaining: 4.88s
# 619:	learn: 0.0290702	total: 7.93s	remaining: 4.86s
# 620:	learn: 0.0290517	total: 7.94s	remaining: 4.84s
# 621:	learn: 0.0290369	total: 7.99s	remaining: 4.85s
# 622:	learn: 0.0290238	total: 8s	remaining: 4.84s
# 623:	learn: 0.0290106	total: 8.03s	remaining: 4.84s
# 624:	learn: 0.0289873	total: 8.04s	remaining: 4.82s
# 625:	learn: 0.0289630	total: 8.06s	remaining: 4.82s
# 626:	learn: 0.0289399	total: 8.08s	remaining: 4.81s
# 627:	learn: 0.0289264	total: 8.09s	remaining: 4.79s
# 628:	learn: 0.0289110	total: 8.11s	remaining: 4.79s
# 629:	learn: 0.0289008	total: 8.13s	remaining: 4.78s
# 630:	learn: 0.0288845	total: 8.17s	remaining: 4.78s
# 631:	learn: 0.0288687	total: 8.17s	remaining: 4.76s
# 632:	learn: 0.0288674	total: 8.2s	remaining: 4.75s
# 633:	learn: 0.0288518	total: 8.24s	remaining: 4.76s
# 634:	learn: 0.0288437	total: 8.26s	remaining: 4.75s
# 635:	learn: 0.0288289	total: 8.27s	remaining: 4.74s
# 636:	learn: 0.0288175	total: 8.28s	remaining: 4.72s
# 637:	learn: 0.0288023	total: 8.3s	remaining: 4.71s
# 638:	learn: 0.0287806	total: 8.32s	remaining: 4.7s
# 639:	learn: 0.0287660	total: 8.34s	remaining: 4.69s
# 640:	learn: 0.0287445	total: 8.36s	remaining: 4.68s
# 641:	learn: 0.0287328	total: 8.37s	remaining: 4.67s
# 642:	learn: 0.0287161	total: 8.37s	remaining: 4.65s
# 643:	learn: 0.0287033	total: 8.38s	remaining: 4.63s
# 644:	learn: 0.0286866	total: 8.39s	remaining: 4.62s
# 645:	learn: 0.0286559	total: 8.4s	remaining: 4.61s
# 646:	learn: 0.0286420	total: 8.42s	remaining: 4.59s
# 647:	learn: 0.0286331	total: 8.43s	remaining: 4.58s
# 648:	learn: 0.0286130	total: 8.43s	remaining: 4.56s
# 649:	learn: 0.0285917	total: 8.45s	remaining: 4.55s
# 650:	learn: 0.0285724	total: 8.46s	remaining: 4.54s
# 651:	learn: 0.0285668	total: 8.47s	remaining: 4.52s
# 652:	learn: 0.0285569	total: 8.48s	remaining: 4.51s
# 653:	learn: 0.0285503	total: 8.5s	remaining: 4.5s
# 654:	learn: 0.0285363	total: 8.51s	remaining: 4.48s
# 655:	learn: 0.0285292	total: 8.51s	remaining: 4.46s
# 656:	learn: 0.0285119	total: 8.53s	remaining: 4.45s
# 657:	learn: 0.0284957	total: 8.53s	remaining: 4.43s
# 658:	learn: 0.0284805	total: 8.54s	remaining: 4.42s
# 659:	learn: 0.0284631	total: 8.55s	remaining: 4.41s
# 660:	learn: 0.0284456	total: 8.56s	remaining: 4.39s
# 661:	learn: 0.0284324	total: 8.56s	remaining: 4.37s
# 662:	learn: 0.0284138	total: 8.57s	remaining: 4.36s
# 663:	learn: 0.0283980	total: 8.58s	remaining: 4.34s
# 664:	learn: 0.0283816	total: 8.58s	remaining: 4.32s
# 665:	learn: 0.0283716	total: 8.59s	remaining: 4.31s
# 666:	learn: 0.0283582	total: 8.62s	remaining: 4.3s
# 667:	learn: 0.0283487	total: 8.65s	remaining: 4.3s
# 668:	learn: 0.0283382	total: 8.68s	remaining: 4.3s
# 669:	learn: 0.0283229	total: 8.69s	remaining: 4.28s
# 670:	learn: 0.0282900	total: 8.72s	remaining: 4.27s
# 671:	learn: 0.0282840	total: 8.76s	remaining: 4.27s
# 672:	learn: 0.0282653	total: 8.77s	remaining: 4.26s
# 673:	learn: 0.0282477	total: 8.78s	remaining: 4.25s
# 674:	learn: 0.0282299	total: 8.79s	remaining: 4.23s
# 675:	learn: 0.0282225	total: 8.79s	remaining: 4.21s
# 676:	learn: 0.0282095	total: 8.82s	remaining: 4.21s
# 677:	learn: 0.0281992	total: 8.83s	remaining: 4.19s
# 678:	learn: 0.0281862	total: 8.86s	remaining: 4.19s
# 679:	learn: 0.0281681	total: 8.87s	remaining: 4.17s
# 680:	learn: 0.0281435	total: 8.88s	remaining: 4.16s
# 681:	learn: 0.0281210	total: 8.91s	remaining: 4.16s
# 682:	learn: 0.0281093	total: 8.93s	remaining: 4.14s
# 683:	learn: 0.0281005	total: 8.94s	remaining: 4.13s
# 684:	learn: 0.0280864	total: 8.96s	remaining: 4.12s
# 685:	learn: 0.0280745	total: 8.96s	remaining: 4.1s
# 686:	learn: 0.0280603	total: 8.99s	remaining: 4.1s
# 687:	learn: 0.0280359	total: 9.09s	remaining: 4.12s
# 688:	learn: 0.0280323	total: 9.15s	remaining: 4.13s
# 689:	learn: 0.0280092	total: 9.17s	remaining: 4.12s
# 690:	learn: 0.0279957	total: 9.18s	remaining: 4.1s
# 691:	learn: 0.0279886	total: 9.19s	remaining: 4.09s
# 692:	learn: 0.0279662	total: 9.23s	remaining: 4.09s
# 693:	learn: 0.0279461	total: 9.26s	remaining: 4.08s
# 694:	learn: 0.0279331	total: 9.27s	remaining: 4.07s
# 695:	learn: 0.0279063	total: 9.32s	remaining: 4.07s
# 696:	learn: 0.0278967	total: 9.33s	remaining: 4.06s
# 697:	learn: 0.0278861	total: 9.37s	remaining: 4.05s
# 698:	learn: 0.0278758	total: 9.4s	remaining: 4.05s
# 699:	learn: 0.0278570	total: 9.44s	remaining: 4.04s
# 700:	learn: 0.0278412	total: 9.46s	remaining: 4.04s
# 701:	learn: 0.0278288	total: 9.47s	remaining: 4.02s
# 702:	learn: 0.0278138	total: 9.49s	remaining: 4.01s
# 703:	learn: 0.0278107	total: 9.56s	remaining: 4.02s
# 704:	learn: 0.0277950	total: 9.6s	remaining: 4.02s
# 705:	learn: 0.0277748	total: 9.62s	remaining: 4.01s
# 706:	learn: 0.0277584	total: 9.63s	remaining: 3.99s
# 707:	learn: 0.0277484	total: 9.69s	remaining: 4s
# 708:	learn: 0.0277408	total: 9.7s	remaining: 3.98s
# 709:	learn: 0.0277294	total: 9.7s	remaining: 3.96s
# 710:	learn: 0.0277238	total: 9.71s	remaining: 3.95s
# 711:	learn: 0.0277109	total: 9.72s	remaining: 3.93s
# 712:	learn: 0.0276923	total: 9.75s	remaining: 3.92s
# 713:	learn: 0.0276717	total: 9.8s	remaining: 3.92s
# 714:	learn: 0.0276554	total: 9.81s	remaining: 3.91s
# 715:	learn: 0.0276271	total: 9.84s	remaining: 3.9s
# 716:	learn: 0.0276120	total: 9.85s	remaining: 3.89s
# 717:	learn: 0.0275985	total: 9.9s	remaining: 3.89s
# 718:	learn: 0.0275800	total: 9.91s	remaining: 3.87s
# 719:	learn: 0.0275632	total: 9.93s	remaining: 3.86s
# 720:	learn: 0.0275510	total: 9.95s	remaining: 3.85s
# 721:	learn: 0.0275469	total: 9.97s	remaining: 3.84s
# 722:	learn: 0.0275343	total: 9.98s	remaining: 3.82s
# 723:	learn: 0.0275191	total: 9.99s	remaining: 3.81s
# 724:	learn: 0.0274946	total: 10s	remaining: 3.79s
# 725:	learn: 0.0274668	total: 10s	remaining: 3.78s
# 726:	learn: 0.0274580	total: 10s	remaining: 3.76s
# 727:	learn: 0.0274449	total: 10s	remaining: 3.74s
# 728:	learn: 0.0274338	total: 10s	remaining: 3.73s
# 729:	learn: 0.0274074	total: 10s	remaining: 3.71s
# 730:	learn: 0.0273891	total: 10s	remaining: 3.69s
# 731:	learn: 0.0273681	total: 10.1s	remaining: 3.68s
# 732:	learn: 0.0273546	total: 10.1s	remaining: 3.67s
# 733:	learn: 0.0273450	total: 10.1s	remaining: 3.65s
# 734:	learn: 0.0273266	total: 10.1s	remaining: 3.63s
# 735:	learn: 0.0273082	total: 10.1s	remaining: 3.62s
# 736:	learn: 0.0272911	total: 10.1s	remaining: 3.61s
# 737:	learn: 0.0272793	total: 10.1s	remaining: 3.59s
# 738:	learn: 0.0272582	total: 10.1s	remaining: 3.58s
# 739:	learn: 0.0272481	total: 10.1s	remaining: 3.56s
# 740:	learn: 0.0272362	total: 10.1s	remaining: 3.54s
# 741:	learn: 0.0272233	total: 10.2s	remaining: 3.53s
# 742:	learn: 0.0272080	total: 10.2s	remaining: 3.52s
# 743:	learn: 0.0271940	total: 10.2s	remaining: 3.5s
# 744:	learn: 0.0271747	total: 10.2s	remaining: 3.49s
# 745:	learn: 0.0271673	total: 10.2s	remaining: 3.47s
# 746:	learn: 0.0271525	total: 10.2s	remaining: 3.46s
# 747:	learn: 0.0271394	total: 10.2s	remaining: 3.44s
# 748:	learn: 0.0271304	total: 10.2s	remaining: 3.42s
# 749:	learn: 0.0271173	total: 10.2s	remaining: 3.41s
# 750:	learn: 0.0271023	total: 10.2s	remaining: 3.39s
# 751:	learn: 0.0270934	total: 10.2s	remaining: 3.38s
# 752:	learn: 0.0270719	total: 10.2s	remaining: 3.36s
# 753:	learn: 0.0270630	total: 10.3s	remaining: 3.35s
# 754:	learn: 0.0270459	total: 10.3s	remaining: 3.33s
# 755:	learn: 0.0270282	total: 10.3s	remaining: 3.31s
# 756:	learn: 0.0270167	total: 10.3s	remaining: 3.3s
# 757:	learn: 0.0269981	total: 10.3s	remaining: 3.28s
# 758:	learn: 0.0269804	total: 10.3s	remaining: 3.27s
# 759:	learn: 0.0269695	total: 10.3s	remaining: 3.25s
# 760:	learn: 0.0269638	total: 10.3s	remaining: 3.24s
# 761:	learn: 0.0269518	total: 10.3s	remaining: 3.22s
# 762:	learn: 0.0269396	total: 10.3s	remaining: 3.21s
# 763:	learn: 0.0269314	total: 10.4s	remaining: 3.2s
# 764:	learn: 0.0269227	total: 10.4s	remaining: 3.19s
# 765:	learn: 0.0269038	total: 10.4s	remaining: 3.18s
# 766:	learn: 0.0268972	total: 10.4s	remaining: 3.16s
# 767:	learn: 0.0268862	total: 10.4s	remaining: 3.15s
# 768:	learn: 0.0268788	total: 10.4s	remaining: 3.13s
# 769:	learn: 0.0268575	total: 10.5s	remaining: 3.12s
# 770:	learn: 0.0268437	total: 10.5s	remaining: 3.11s
# 771:	learn: 0.0268335	total: 10.5s	remaining: 3.09s
# 772:	learn: 0.0268150	total: 10.5s	remaining: 3.07s
# 773:	learn: 0.0267949	total: 10.5s	remaining: 3.06s
# 774:	learn: 0.0267707	total: 10.5s	remaining: 3.04s
# 775:	learn: 0.0267661	total: 10.5s	remaining: 3.03s
# 776:	learn: 0.0267518	total: 10.5s	remaining: 3.01s
# 777:	learn: 0.0267418	total: 10.5s	remaining: 3s
# 778:	learn: 0.0267237	total: 10.5s	remaining: 2.98s
# 779:	learn: 0.0267130	total: 10.5s	remaining: 2.97s
# 780:	learn: 0.0267044	total: 10.5s	remaining: 2.95s
# 781:	learn: 0.0266859	total: 10.5s	remaining: 2.94s
# 782:	learn: 0.0266690	total: 10.5s	remaining: 2.92s
# 783:	learn: 0.0266565	total: 10.6s	remaining: 2.91s
# 784:	learn: 0.0266501	total: 10.6s	remaining: 2.89s
# 785:	learn: 0.0266363	total: 10.6s	remaining: 2.88s
# 786:	learn: 0.0266252	total: 10.6s	remaining: 2.86s
# 787:	learn: 0.0266121	total: 10.6s	remaining: 2.85s
# 788:	learn: 0.0266056	total: 10.6s	remaining: 2.84s
# 789:	learn: 0.0265853	total: 10.6s	remaining: 2.82s
# 790:	learn: 0.0265676	total: 10.6s	remaining: 2.81s
# 791:	learn: 0.0265609	total: 10.6s	remaining: 2.79s
# 792:	learn: 0.0265449	total: 10.7s	remaining: 2.78s
# 793:	learn: 0.0265342	total: 10.7s	remaining: 2.77s
# 794:	learn: 0.0265183	total: 10.7s	remaining: 2.76s
# 795:	learn: 0.0265045	total: 10.7s	remaining: 2.75s
# 796:	learn: 0.0264886	total: 10.7s	remaining: 2.73s
# 797:	learn: 0.0264698	total: 10.8s	remaining: 2.73s
# 798:	learn: 0.0264567	total: 10.8s	remaining: 2.71s
# 799:	learn: 0.0264407	total: 10.8s	remaining: 2.7s
# 800:	learn: 0.0264280	total: 10.8s	remaining: 2.69s
# 801:	learn: 0.0264139	total: 10.8s	remaining: 2.67s
# 802:	learn: 0.0264005	total: 10.8s	remaining: 2.66s
# 803:	learn: 0.0263922	total: 10.8s	remaining: 2.64s
# 804:	learn: 0.0263811	total: 10.8s	remaining: 2.63s
# 805:	learn: 0.0263688	total: 10.9s	remaining: 2.61s
# 806:	learn: 0.0263478	total: 10.9s	remaining: 2.6s
# 807:	learn: 0.0263278	total: 10.9s	remaining: 2.58s
# 808:	learn: 0.0263145	total: 10.9s	remaining: 2.57s
# 809:	learn: 0.0262948	total: 10.9s	remaining: 2.55s
# 810:	learn: 0.0262794	total: 10.9s	remaining: 2.54s
# 811:	learn: 0.0262629	total: 10.9s	remaining: 2.52s
# 812:	learn: 0.0262483	total: 10.9s	remaining: 2.51s
# 813:	learn: 0.0262357	total: 10.9s	remaining: 2.49s
# 814:	learn: 0.0262070	total: 10.9s	remaining: 2.48s
# 815:	learn: 0.0261927	total: 10.9s	remaining: 2.46s
# 816:	learn: 0.0261727	total: 10.9s	remaining: 2.45s
# 817:	learn: 0.0261658	total: 10.9s	remaining: 2.43s
# 818:	learn: 0.0261561	total: 10.9s	remaining: 2.42s
# 819:	learn: 0.0261296	total: 10.9s	remaining: 2.4s
# 820:	learn: 0.0261201	total: 10.9s	remaining: 2.39s
# 821:	learn: 0.0261095	total: 11s	remaining: 2.37s
# 822:	learn: 0.0260971	total: 11s	remaining: 2.36s
# 823:	learn: 0.0260826	total: 11s	remaining: 2.34s
# 824:	learn: 0.0260774	total: 11s	remaining: 2.33s
# 825:	learn: 0.0260608	total: 11s	remaining: 2.31s
# 826:	learn: 0.0260580	total: 11s	remaining: 2.29s
# 827:	learn: 0.0260508	total: 11s	remaining: 2.28s
# 828:	learn: 0.0260362	total: 11s	remaining: 2.27s
# 829:	learn: 0.0260194	total: 11s	remaining: 2.25s
# 830:	learn: 0.0259999	total: 11s	remaining: 2.24s
# 831:	learn: 0.0259948	total: 11s	remaining: 2.22s
# 832:	learn: 0.0259767	total: 11s	remaining: 2.21s
# 833:	learn: 0.0259571	total: 11s	remaining: 2.19s
# 834:	learn: 0.0259424	total: 11s	remaining: 2.18s
# 835:	learn: 0.0259308	total: 11s	remaining: 2.16s
# 836:	learn: 0.0259229	total: 11s	remaining: 2.15s
# 837:	learn: 0.0259163	total: 11s	remaining: 2.13s
# 838:	learn: 0.0259088	total: 11s	remaining: 2.12s
# 839:	learn: 0.0258966	total: 11s	remaining: 2.1s
# 840:	learn: 0.0258844	total: 11s	remaining: 2.09s
# 841:	learn: 0.0258687	total: 11s	remaining: 2.07s
# 842:	learn: 0.0258527	total: 11.1s	remaining: 2.06s
# 843:	learn: 0.0258443	total: 11.1s	remaining: 2.04s
# 844:	learn: 0.0258402	total: 11.1s	remaining: 2.03s
# 845:	learn: 0.0258255	total: 11.1s	remaining: 2.02s
# 846:	learn: 0.0258136	total: 11.1s	remaining: 2s
# 847:	learn: 0.0257973	total: 11.1s	remaining: 1.99s
# 848:	learn: 0.0257818	total: 11.1s	remaining: 1.97s
# 849:	learn: 0.0257730	total: 11.1s	remaining: 1.96s
# 850:	learn: 0.0257609	total: 11.1s	remaining: 1.94s
# 851:	learn: 0.0257539	total: 11.1s	remaining: 1.93s
# 852:	learn: 0.0257302	total: 11.1s	remaining: 1.92s
# 853:	learn: 0.0257161	total: 11.1s	remaining: 1.9s
# 854:	learn: 0.0257008	total: 11.1s	remaining: 1.89s
# 855:	learn: 0.0256931	total: 11.1s	remaining: 1.87s
# 856:	learn: 0.0256777	total: 11.1s	remaining: 1.86s
# 857:	learn: 0.0256741	total: 11.1s	remaining: 1.84s
# 858:	learn: 0.0256572	total: 11.1s	remaining: 1.83s
# 859:	learn: 0.0256462	total: 11.1s	remaining: 1.81s
# 860:	learn: 0.0256378	total: 11.1s	remaining: 1.8s
# 861:	learn: 0.0256256	total: 11.2s	remaining: 1.78s
# 862:	learn: 0.0256176	total: 11.2s	remaining: 1.77s
# 863:	learn: 0.0256084	total: 11.2s	remaining: 1.76s
# 864:	learn: 0.0256000	total: 11.2s	remaining: 1.74s
# 865:	learn: 0.0255798	total: 11.2s	remaining: 1.73s
# 866:	learn: 0.0255626	total: 11.2s	remaining: 1.71s
# 867:	learn: 0.0255528	total: 11.2s	remaining: 1.7s
# 868:	learn: 0.0255419	total: 11.2s	remaining: 1.69s
# 869:	learn: 0.0255355	total: 11.2s	remaining: 1.67s
# 870:	learn: 0.0255156	total: 11.2s	remaining: 1.66s
# 871:	learn: 0.0255053	total: 11.2s	remaining: 1.65s
# 872:	learn: 0.0254831	total: 11.2s	remaining: 1.63s
# 873:	learn: 0.0254721	total: 11.2s	remaining: 1.62s
# 874:	learn: 0.0254570	total: 11.2s	remaining: 1.61s
# 875:	learn: 0.0254496	total: 11.2s	remaining: 1.59s
# 876:	learn: 0.0254362	total: 11.3s	remaining: 1.58s
# 877:	learn: 0.0254251	total: 11.3s	remaining: 1.56s
# 878:	learn: 0.0254205	total: 11.3s	remaining: 1.55s
# 879:	learn: 0.0254088	total: 11.3s	remaining: 1.54s
# 880:	learn: 0.0253991	total: 11.3s	remaining: 1.52s
# 881:	learn: 0.0253880	total: 11.3s	remaining: 1.51s
# 882:	learn: 0.0253781	total: 11.3s	remaining: 1.5s
# 883:	learn: 0.0253658	total: 11.3s	remaining: 1.48s
# 884:	learn: 0.0253464	total: 11.3s	remaining: 1.47s
# 885:	learn: 0.0253328	total: 11.3s	remaining: 1.45s
# 886:	learn: 0.0253198	total: 11.3s	remaining: 1.44s
# 887:	learn: 0.0253147	total: 11.3s	remaining: 1.43s
# 888:	learn: 0.0253034	total: 11.3s	remaining: 1.42s
# 889:	learn: 0.0252972	total: 11.4s	remaining: 1.4s
# 890:	learn: 0.0252901	total: 11.4s	remaining: 1.39s
# 891:	learn: 0.0252753	total: 11.4s	remaining: 1.38s
# 892:	learn: 0.0252610	total: 11.4s	remaining: 1.36s
# 893:	learn: 0.0252508	total: 11.4s	remaining: 1.35s
# 894:	learn: 0.0252340	total: 11.4s	remaining: 1.34s
# 895:	learn: 0.0252143	total: 11.5s	remaining: 1.33s
# 896:	learn: 0.0251990	total: 11.5s	remaining: 1.32s
# 897:	learn: 0.0251894	total: 11.5s	remaining: 1.31s
# 898:	learn: 0.0251741	total: 11.5s	remaining: 1.29s
# 899:	learn: 0.0251592	total: 11.5s	remaining: 1.28s
# 900:	learn: 0.0251500	total: 11.6s	remaining: 1.27s
# 901:	learn: 0.0251366	total: 11.6s	remaining: 1.26s
# 902:	learn: 0.0251236	total: 11.6s	remaining: 1.25s
# 903:	learn: 0.0251159	total: 11.6s	remaining: 1.23s
# 904:	learn: 0.0251059	total: 11.7s	remaining: 1.22s
# 905:	learn: 0.0250887	total: 11.7s	remaining: 1.21s
# 906:	learn: 0.0250814	total: 11.7s	remaining: 1.2s
# 907:	learn: 0.0250748	total: 11.7s	remaining: 1.18s
# 908:	learn: 0.0250606	total: 11.7s	remaining: 1.17s
# 909:	learn: 0.0250537	total: 11.7s	remaining: 1.16s
# 910:	learn: 0.0250405	total: 11.7s	remaining: 1.14s
# 911:	learn: 0.0250295	total: 11.7s	remaining: 1.13s
# 912:	learn: 0.0250127	total: 11.7s	remaining: 1.11s
# 913:	learn: 0.0250019	total: 11.7s	remaining: 1.1s
# 914:	learn: 0.0249857	total: 11.8s	remaining: 1.09s
# 915:	learn: 0.0249684	total: 11.8s	remaining: 1.08s
# 916:	learn: 0.0249626	total: 11.8s	remaining: 1.07s
# 917:	learn: 0.0249490	total: 11.8s	remaining: 1.06s
# 918:	learn: 0.0249362	total: 11.8s	remaining: 1.04s
# 919:	learn: 0.0249250	total: 11.8s	remaining: 1.03s
# 920:	learn: 0.0249169	total: 11.9s	remaining: 1.02s
# 921:	learn: 0.0248988	total: 11.9s	remaining: 1s
# 922:	learn: 0.0248904	total: 11.9s	remaining: 992ms
# 923:	learn: 0.0248830	total: 11.9s	remaining: 979ms
# 924:	learn: 0.0248693	total: 11.9s	remaining: 966ms
# 925:	learn: 0.0248626	total: 11.9s	remaining: 952ms
# 926:	learn: 0.0248482	total: 11.9s	remaining: 939ms
# 927:	learn: 0.0248371	total: 11.9s	remaining: 925ms
# 928:	learn: 0.0248298	total: 11.9s	remaining: 912ms
# 929:	learn: 0.0248163	total: 11.9s	remaining: 898ms
# 930:	learn: 0.0248060	total: 11.9s	remaining: 885ms
# 931:	learn: 0.0247817	total: 11.9s	remaining: 872ms
# 932:	learn: 0.0247751	total: 12s	remaining: 859ms
# 933:	learn: 0.0247582	total: 12s	remaining: 845ms
# 934:	learn: 0.0247459	total: 12s	remaining: 833ms
# 935:	learn: 0.0247375	total: 12s	remaining: 821ms
# 936:	learn: 0.0247302	total: 12s	remaining: 808ms
# 937:	learn: 0.0247172	total: 12s	remaining: 795ms
# 938:	learn: 0.0247058	total: 12s	remaining: 782ms
# 939:	learn: 0.0247003	total: 12.1s	remaining: 770ms
# 940:	learn: 0.0246907	total: 12.1s	remaining: 757ms
# 941:	learn: 0.0246829	total: 12.1s	remaining: 744ms
# 942:	learn: 0.0246717	total: 12.1s	remaining: 730ms
# 943:	learn: 0.0246600	total: 12.1s	remaining: 717ms
# 944:	learn: 0.0246476	total: 12.1s	remaining: 704ms
# 945:	learn: 0.0246401	total: 12.1s	remaining: 691ms
# 946:	learn: 0.0246301	total: 12.1s	remaining: 677ms
# 947:	learn: 0.0246186	total: 12.1s	remaining: 664ms
# 948:	learn: 0.0245974	total: 12.1s	remaining: 651ms
# 949:	learn: 0.0245729	total: 12.1s	remaining: 638ms
# 950:	learn: 0.0245639	total: 12.1s	remaining: 625ms
# 951:	learn: 0.0245470	total: 12.1s	remaining: 611ms
# 952:	learn: 0.0245403	total: 12.1s	remaining: 598ms
# 953:	learn: 0.0245297	total: 12.1s	remaining: 585ms
# 954:	learn: 0.0245186	total: 12.1s	remaining: 572ms
# 955:	learn: 0.0245064	total: 12.2s	remaining: 560ms
# 956:	learn: 0.0245017	total: 12.2s	remaining: 547ms
# 957:	learn: 0.0244980	total: 12.2s	remaining: 534ms
# 958:	learn: 0.0244839	total: 12.2s	remaining: 521ms
# 959:	learn: 0.0244780	total: 12.2s	remaining: 507ms
# 960:	learn: 0.0244582	total: 12.2s	remaining: 494ms
# 961:	learn: 0.0244527	total: 12.2s	remaining: 481ms
# 962:	learn: 0.0244441	total: 12.2s	remaining: 469ms
# 963:	learn: 0.0244288	total: 12.2s	remaining: 456ms
# 964:	learn: 0.0244152	total: 12.2s	remaining: 444ms
# 965:	learn: 0.0244069	total: 12.2s	remaining: 431ms
# 966:	learn: 0.0243955	total: 12.3s	remaining: 418ms
# 967:	learn: 0.0243827	total: 12.3s	remaining: 406ms
# 968:	learn: 0.0243678	total: 12.3s	remaining: 393ms
# 969:	learn: 0.0243590	total: 12.3s	remaining: 380ms
# 970:	learn: 0.0243529	total: 12.3s	remaining: 367ms
# 971:	learn: 0.0243348	total: 12.3s	remaining: 355ms
# 972:	learn: 0.0243169	total: 12.3s	remaining: 342ms
# 973:	learn: 0.0243074	total: 12.3s	remaining: 329ms
# 974:	learn: 0.0242968	total: 12.3s	remaining: 316ms
# 975:	learn: 0.0242823	total: 12.3s	remaining: 303ms
# 976:	learn: 0.0242733	total: 12.3s	remaining: 291ms
# 977:	learn: 0.0242665	total: 12.3s	remaining: 278ms
# 978:	learn: 0.0242586	total: 12.4s	remaining: 265ms
# 979:	learn: 0.0242425	total: 12.4s	remaining: 252ms
# 980:	learn: 0.0242367	total: 12.4s	remaining: 240ms
# 981:	learn: 0.0242363	total: 12.4s	remaining: 227ms
# 982:	learn: 0.0242280	total: 12.4s	remaining: 215ms
# 983:	learn: 0.0242192	total: 12.4s	remaining: 202ms
# 984:	learn: 0.0242144	total: 12.4s	remaining: 189ms
# 985:	learn: 0.0242036	total: 12.4s	remaining: 177ms
# 986:	learn: 0.0241896	total: 12.5s	remaining: 164ms
# 987:	learn: 0.0241823	total: 12.5s	remaining: 151ms
# 988:	learn: 0.0241688	total: 12.5s	remaining: 139ms
# 989:	learn: 0.0241566	total: 12.5s	remaining: 126ms
# 990:	learn: 0.0241435	total: 12.5s	remaining: 113ms
# 991:	learn: 0.0241305	total: 12.5s	remaining: 101ms
# 992:	learn: 0.0241231	total: 12.5s	remaining: 88.3ms
# 993:	learn: 0.0241183	total: 12.5s	remaining: 75.7ms
# 994:	learn: 0.0241086	total: 12.6s	remaining: 63.1ms
# 995:	learn: 0.0241028	total: 12.6s	remaining: 50.5ms
# 996:	learn: 0.0240906	total: 12.6s	remaining: 37.9ms
# 997:	learn: 0.0240824	total: 12.6s	remaining: 25.3ms
# 998:	learn: 0.0240681	total: 12.6s	remaining: 12.6ms
# 999:	learn: 0.0240566	total: 12.6s	remaining: 0us
# TEST: R2: 0.7846206536106863, MSE: 0.0016369842338540333, RMSE: 0.040459661810920186

# %%
cb.save_model('/Users/igorkim/Documents/GitHub/hse_final_project/ml/0_data/catboost_model',
           format="cbm")

# %% [markdown]
# ## Проверка предсказания для новой точки

# %%
test_test = pd.read_csv('/Users/igorkim/Downloads/test_test.csv')

# %%
test_test = test_test[['atm_group', 'distance_to_retail', 'distance_to_apartments',
       'distance_to_commercial', 'distance_to_office',
       'distance_to_train_station', 'distance_to_residential',
       'distance_to_house', 'distance_to_detached', 'distance_to_supermarket',
       'distance_to_cinema', 'distance_to_pharmacy', 'distance_to_cafe',
       'distance_to_bank', 'distance_to_sber_bank', 'distance_to_restaurant',
       'distance_to_sber_atm', 'distance_to_atm', 'distance_to_fast_food',
       'distance_to_vtb_bank', 'distance_to_convenience',
       'distance_to_clothes', 'distance_to_mobile_phone_shop',
       'distance_to_shoe_shop', 'distance_to_vending_any',
       'distance_to_alfa_bank', 'distance_to_vtb_atm', 'distance_to_ros_bank',
       'distance_to_alfa_atm', 'distance_to_ros_atm',
       'distance_to_vending_parking', 'distance_to_bus_stop',
       'distance_to_railway_station', 'distance_to_tram_stop',
       'distance_to_railway_halt', 'distance_to_airport',
       'distance_to_parking', 'distance_to_parking_underground', 'cities',
       'regions', 'states', 'population', 'salary', 'population_density',
       'happy_index', 'avgC', 'avgR', 'avgS', 'avgA', 'capital']]

# %%
cb.predict(test_test)
# Out:
# array([0.02242874])
