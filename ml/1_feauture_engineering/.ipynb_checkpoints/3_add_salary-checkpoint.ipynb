# %%
import pandas as pd
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
data = pd.read_csv('/Users/igorkim/Desktop/ВШЭ/ ВКР/data/data_with_OSM')

# %%
len(data)
# Out:
# 5957

# %%
data.isnull().sum()
# Out:
# id                                    0
# atm_group                             0
# address                               0
# address_rus                           0
# lat                                   0
# lon                                   0
# target                                0
# geometry                              0
# distance_to_retail                  285
# distance_to_apartments              131
# distance_to_commercial              330
# distance_to_office                  896
# distance_to_train_station          1438
# distance_to_residential             478
# distance_to_house                   147
# distance_to_detached                952
# distance_to_supermarket             212
# distance_to_cinema                 1172
# distance_to_pharmacy                205
# distance_to_cafe                    214
# distance_to_bank                    268
# distance_to_sber_bank               538
# distance_to_restaurant              568
# distance_to_sber_atm               1737
# distance_to_atm                     347
# distance_to_fast_food               477
# distance_to_vtb_bank               1422
# distance_to_convenience             139
# distance_to_clothes                 499
# distance_to_mobile_phone_shop       168
# distance_to_shoe_shop               813
# distance_to_vending_any            2060
# distance_to_alfa_bank              2180
# distance_to_vtb_atm                3978
# distance_to_ros_bank               2968
# distance_to_alfa_atm               3843
# distance_to_ros_atm                4445
# distance_to_vending_parking        4535
# distance_to_bus_stop                114
# distance_to_railway_station         738
# distance_to_tram_stop              3017
# distance_to_railway_halt           1578
# distance_to_airport                5786
# distance_to_parking                 610
# distance_to_parking_underground    3479
# cities                                0
# regions                               1
# states                                0
# dtype: int64

# %%
#1 пропущенный регион - это южный федеральный округ
data['regions'] = data['regions'].replace(np.nan, 'Southern Federal District')

# %%
df_regions = pd.read_csv('/Users/igorkim/Documents/GitHub/hse_final_project/ml/0_data/regions_data.csv', sep = ';')

# %%
data = data.merge(df_regions, how = 'inner', left_on = 'regions', right_on = 'Unnamed: 0').drop('Unnamed: 0', axis = 1)

# %%
data.head()
# Out:
#        id  atm_group                                 address  \
# 0  8526.0       32.0  EMELYANOVA,34          Y-SAKHALINSK
# 1  8532.0       32.0  KOMSOMOLSKAYA,259B     Y.SAKHALINSK
# 2  8533.0       32.0  KOMMUN. PR., 32        YUZHNO SAKHAL
# 3   313.0       32.0  RUSSKAYA, 16           VLADIVOSTOK
# 4   358.0       32.0  ADMIRALA FOKINA, 25    VLADIVOSTOK
#
#                                          address_rus        lat         lon  \
# 0  улица А.О. Емельянова, 34, Южно-Сахалинск, Сах...  46.940995  142.738319
# 1  Комсомольская улица, 259, Южно-Сахалинск, Саха...  46.937353  142.753348
# 2  Коммунистический проспект, Южно-Сахалинск, Сах...  46.959413  142.741113
# 3  Русская улица, 16, Владивосток, Приморский кра...  43.165860  131.908212
# 4  улица Адмирала Фокина, 25, Владивосток, Примор...  43.117174  131.885503
#
#      target                                       geometry  \
# 0  0.011500   POINT (15889556.987767845 5932448.267111904)
# 1  0.029710  POINT (15891230.008394975 5931854.4756764155)
# 2  0.009540   POINT (15889868.014425125 5935451.755418368)
# 3 -0.145001   POINT (14683954.991291177 5337251.601561674)
# 4 -0.133426   POINT (14681427.036974752 5329823.964936375)
#
#    distance_to_retail  distance_to_apartments  ...  distance_to_airport  \
# 0            7.538905              216.343704  ...                  NaN
# 1          272.351877                9.606115  ...                  NaN
# 2          428.158970              177.741156  ...                  NaN
# 3          294.553866              196.258001  ...                  NaN
# 4          267.258031              123.051116  ...                  NaN
#
#    distance_to_parking  distance_to_parking_underground             cities  \
# 0          2892.577916                      2346.129844  Yuzhno-Sakhalinsk
# 1          2767.793411                      2124.799118  Yuzhno-Sakhalinsk
# 2          1815.884777                      1864.222802  Yuzhno-Sakhalinsk
# 3           736.919210                              NaN        Vladivostok
# 4          8248.742223                              NaN        Vladivostok
#
#                         regions           states  population  salary  \
# 0  Far Eastern Federal District  Sakhalin Oblast     8124053   42000
# 1  Far Eastern Federal District  Sakhalin Oblast     8124053   42000
# 2  Far Eastern Federal District  Sakhalin Oblast     8124053   42000
# 3  Far Eastern Federal District   Primorsky Krai     8124053   42000
# 4  Far Eastern Federal District   Primorsky Krai     8124053   42000
#
#    population_density  happy_index
# 0            1.168499           77
# 1            1.168499           77
# 2            1.168499           77
# 3            1.168499           77
# 4            1.168499           77
#
# [5 rows x 52 columns]

# %%
data = data.merge(data.groupby('cities').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgC'}),
         how='left', on='cities')

data = data.merge(data.groupby('regions').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgR'}),
         how='left', on='regions')

data = data.merge(data.groupby('states').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgS'}),
         how='left', on='states')

data = data.merge(data.groupby('atm_group').agg({'target': 'mean'}).reset_index().rename(columns={'target': 'avgA'}),
         how='left', on='atm_group')

# %%
data['capital'] = np.where((data['cities'] == 'Moscow') | (data['cities'] == 'Saint Petersburg'), 1, 0)

# %%
data.to_csv('/Users/igorkim/Documents/GitHub/hse_final_project/ml/0_data/expanded_data_with_OSM_v3.csv')
